# %% [markdown]
# ## Amazon Product Bundling & Recommendation

# %%
import pandas as pd
import numpy as np
from datetime import datetime
import pyfpgrowth
from mlxtend.frequent_patterns import association_rules
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, fpmax, fpgrowth
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# LOADING AND PREPROCESSING THE DATA

# %%
# Load Data & Preprocess
file_path = './data/Amazon_2_Raw.xlsx'

# Read the Excel file into a DataFrame
df = pd.read_excel(file_path, sheet_name='Amazon')

# product id to name dictionary 

product_id_to_name = dict(zip(df['Product_ID'], df['Product Name']))

# Display the DataFrame
print(df.head())

# Check for missing values
missing_values = df.isnull().sum()
print("Missing Values:")
# print(missing_values)

# Check for duplicate rows
duplicate_rows = df.duplicated().sum()
# print("Duplicate Rows:", duplicate_rows)

# Check datatype of each column
data_types = df.dtypes
print(data_types)

# Calculate unit price for each transaction
df['Unit Price'] = df['Sales'] / df['Quantity']
# Out:
#          Order ID Order Date  Ship Date   Customer Name        Country  \
# 0  CA-2013-138688 2013-06-13 2013-06-17   DarrinVanHuff  United States
# 1  CA-2011-115812 2011-06-09 2011-06-14  BrosinaHoffman  United States
# 2  CA-2011-115812 2011-06-09 2011-06-14  BrosinaHoffman  United States
# 3  CA-2011-115812 2011-06-09 2011-06-14  BrosinaHoffman  United States
# 4  CA-2011-115812 2011-06-09 2011-06-14  BrosinaHoffman  United States
#
#           City       State     Category Product_ID  \
# 0  Los Angeles  California       Labels  AMZ_P_001
# 1  Los Angeles  California  Furnishings  AMZ_P_002
# 2  Los Angeles  California          Art  AMZ_P_003
# 3  Los Angeles  California       Phones  AMZ_P_004
# 4  Los Angeles  California      Binders  AMZ_P_005
#
#                                         Product Name Product_ID.1    Sales  \
# 0  Self-Adhesive Address Labels for Typewriters b...    AMZ_P_001   14.620
# 1  Eldon Expressions Wood and Plastic Desk Access...    AMZ_P_002   48.860
# 2                                         Newell 322    AMZ_P_003    7.280
# 3                     Mitel 5320 IP Phone VoIP phone    AMZ_P_004  907.152
# 4  DXL Angle-View Binders with Locking Rings by S...    AMZ_P_005   18.504
#
#    Quantity   Profit
# 0         2   6.8714
# 1         7  14.1694
# 2         4   1.9656
# 3         4  90.7152
# 4         3   5.7825
# Missing Values:
# Order ID                 object
# Order Date       datetime64[ns]
# Ship Date        datetime64[ns]
# Customer Name            object
# Country                  object
# City                     object
# State                    object
# Category                 object
# Product_ID               object
# Product Name             object
# Product_ID.1             object
# Sales                   float64
# Quantity                  int64
# Profit                  float64
# dtype: object

# %%
product_id_to_name
# Out:
# {'AMZ_P_001': 'Self-Adhesive Address Labels for Typewriters by Universal',
#  'AMZ_P_002': 'Eldon Expressions Wood and Plastic Desk Accessories, Cherry Wood',
#  'AMZ_P_003': 'Newell 322',
#  'AMZ_P_004': 'Mitel 5320 IP Phone VoIP phone',
#  'AMZ_P_005': 'DXL Angle-View Binders with Locking Rings by Samsill',
#  'AMZ_P_006': 'Belkin F5C206VTEL 6 Outlet Surge',
#  'AMZ_P_007': 'Chromcraft Rectangular Conference Tables',
#  'AMZ_P_008': 'Konftel 250 ConferenceÂ\xa0phoneÂ\xa0- Charcoal black',
#  'AMZ_P_009': 'Fellowes PB200 Plastic Comb Binding Machine',
#  'AMZ_P_010': 'Fellowes Super Stor/Drawer',
#  'AMZ_P_011': 'Newell 341',
#  'AMZ_P_012': 'Cisco SPA 501G IP Phone',
#  'AMZ_P_013': 'Wilson Jones Hanging View Binder, White, 1"',
#  'AMZ_P_014': 'Bretford CR4500 Series Slim Rectangular Table',
#  'AMZ_P_015': 'Wilson Jones Active Use Binders',
#  'AMZ_P_016': 'ImationÂ\xa08GB Mini TravelDrive USB 2.0Â\xa0Flash Drive',
#  'AMZ_P_017': 'Eldon Base for stackable storage shelf, platinum',
#  'AMZ_P_018': 'Verbatim 25 GB 6x Blu-ray Single Layer Recordable Disc, 3/Pack',
#  'AMZ_P_019': 'Acco PRESSTEX Data Binder with Storage Hooks, Dark Blue, 14 7/8" X 11"',
#  'AMZ_P_020': 'Xerox 1943',
#  'AMZ_P_021': 'Luxo Economy Swing Arm Lamp',
#  'AMZ_P_022': 'Hunt BOSTON Model 1606 High-Volume Electric Pencil Sharpener, Beige',
#  'AMZ_P_023': 'netTALK DUO VoIP Telephone Service',
#  'AMZ_P_024': 'Premium Writing Pencils, Soft, #2 by Central Association for the Blind',
#  'AMZ_P_025': 'Sortfiler Multipurpose Personal File Organizer, Black',
#  'AMZ_P_026': 'Turquoise Lead Holder with Pocket Clip',
#  'AMZ_P_027': 'Panasonic Kx-TS550',
#  'AMZ_P_028': 'Xerox 1995',
#  'AMZ_P_029': 'Flexible Leather- Look Classic Collection Ring Binder',
#  'AMZ_P_030': 'Trimflex Flexible Post Binders',
#  'AMZ_P_031': 'Logitech K350 2.4Ghz Wireless Keyboard',
#  'AMZ_P_032': 'Deflect-o DuraMat Lighweight, Studded, Beveled Mat for Low Pile Carpeting',
#  'AMZ_P_033': 'Avery Trapezoid Ring Binder, 3" Capacity, Black, 1040 sheets',
#  'AMZ_P_034': 'Hon Racetrack Conference Tables',
#  'AMZ_P_035': 'Avery Durable Slant Ring Binders, No Labels',
#  'AMZ_P_036': 'Trav-L-File Heavy-Duty Shuttle II, Black',
#  'AMZ_P_037': 'Global Task Chair, Black',
#  'AMZ_P_038': 'Eldon Cleatmat Plus Chair Mats for High Pile Carpets',
#  'AMZ_P_039': 'Xerox 195',
#  'AMZ_P_040': 'Xerox 1880',
#  'AMZ_P_041': 'Sanford Colorific Colored Pencils, 12/Box',
#  'AMZ_P_042': 'Ideal Clamps',
#  'AMZ_P_043': 'GBC Wire Binding Strips',
#  'AMZ_P_044': 'Fiskars Softgrip Scissors',
#  'AMZ_P_045': 'Longer-Life Soft White Bulbs',
#  'AMZ_P_046': 'Newell 343',
#  'AMZ_P_047': 'Convenience Packs of Business Envelopes',
#  'AMZ_P_048': 'Xerox 1911',
#  'AMZ_P_049': 'Safco Industrial Wire Shelving',
#  'AMZ_P_050': 'Belkin 7 Outlet SurgeMaster Surge Protector with Phone Protection',
#  'AMZ_P_051': 'Jabra BIZ 2300 Duo QD Duo CordedÂ\xa0Headset',
#  'AMZ_P_052': 'Southworth 25% Cotton Antique Laid Paper & Envelopes',
#  'AMZ_P_053': 'Xerox 1883',
#  'AMZ_P_054': 'Tenex Personal Project File with Scoop Front Design, Black',
#  'AMZ_P_055': 'Newell 311',
#  'AMZ_P_056': "Global Deluxe High-Back Manager's Chair",
#  'AMZ_P_057': 'Xerox 1920',
#  'AMZ_P_058': 'Staples',
#  'AMZ_P_059': 'Wilson Jones International Size A4 Ring Binders',
#  'AMZ_P_060': 'Adams Phone Message Book, Professional, 400 Message Capacity, 5 3/6Â” x 11Â”',
#  'AMZ_P_061': 'Xerox 1913',
#  'AMZ_P_062': 'Global Value Steno Chair, Gray',
#  'AMZ_P_063': 'SanDisk Ultra 32 GB MicroSDHC Class 10 Memory Card',
#  'AMZ_P_064': 'Poly String Tie Envelopes',
#  'AMZ_P_065': 'BoxOffice By Design Rectangular and Half-Moon Meeting Room Tables',
#  'AMZ_P_066': 'Bravo II Megaboss 12-Amp Hard Body Upright, Replacement Belts, 2 Belts per Pack',
#  'AMZ_P_067': 'Nortel Business Series Terminal T7208 Digital phone',
#  'AMZ_P_068': 'Personal Filing Tote with Lid, Black/Gray',
#  'AMZ_P_069': 'Adtran 1202752G1',
#  'AMZ_P_070': 'Xerox 4200 Series MultiUse Premium Copy Paper (20Lb. and 84 Bright)',
#  'AMZ_P_071': 'Global Leather Highback Executive Chair with Pneumatic Height Adjustment, Black',
#  'AMZ_P_072': 'Wirebound Message Books, Two 4 1/4" x 5" Forms per Page',
#  'AMZ_P_073': 'LogitechÂ\xa0P710e Mobile Speakerphone',
#  'AMZ_P_074': 'Microsoft Sculpt Comfort Mouse',
#  'AMZ_P_075': 'Adjustable Depth Letter/Legal Cart',
#  'AMZ_P_076': 'Logitech 910-002974 M325 Wireless Mouse for Web Scrolling',
#  'AMZ_P_077': 'Regeneration Desk Collection',
#  'AMZ_P_078': 'Presstex Flexible Ring Binders',
#  'AMZ_P_079': 'Ampad Gold Fibre Wirebound Steno Books, 6" x 9", Gregg Ruled',
#  'AMZ_P_080': 'Newell 330',
#  'AMZ_P_081': 'Bevis Round Bullnose 29" High Table Top',
#  'AMZ_P_082': 'Microsoft Arc Touch Mouse',
#  'AMZ_P_083': 'Xerox 216',
#  'AMZ_P_084': 'Howard Miller 13" Diameter Goldtone Round Wall Clock',
#  'AMZ_P_085': 'Global Deluxe Office Fabric Chairs',
#  'AMZ_P_086': 'Eldon ClusterMat Chair Mat with Cordless Antistatic Protection',
#  'AMZ_P_087': 'Ibico Laser Imprintable Binding System Covers',
#  'AMZ_P_088': 'Vinyl Coated Wire Paper Clips in Organizer Box, 800/Box',
#  'AMZ_P_089': 'C-Line Cubicle Keepers Polyproplyene Holder With Velcro Backings',
#  'AMZ_P_090': 'Hon 4070 Series Pagoda Armless Upholstered Stacking Chairs',
#  'AMZ_P_091': 'Eldon Expressions Desk Accessory, Wood Photo Frame, Mahogany',
#  'AMZ_P_092': 'Avery 509',
#  'AMZ_P_093': 'OIC Binder Clips',
#  'AMZ_P_094': 'Logitech Wireless Headset h800',
#  'AMZ_P_095': 'Storex Dura Pro Binders',
#  'AMZ_P_096': 'Hewlett Packard LaserJet 3310 Copier',
#  'AMZ_P_097': 'Avery Non-Stick Binders',
#  'AMZ_P_098': 'Tuff Stuff Recycled Round Ring Binders',
#  'AMZ_P_099': 'Hon 5100 Series Wood Tables',
#  'AMZ_P_100': 'OIC Binder Clips, Mini, 1/4" Capacity, Black',
#  'AMZ_P_101': 'Anker 36W 4-Port USB Wall Charger Travel Power Adapter for iPhone 5s 5c 5',
#  'AMZ_P_102': 'Gould Plastics 9-Pocket Panel Bin, 18-3/8w x 5-1/4d x 20-1/2h, Black',
#  'AMZ_P_103': 'Wilson Jones Custom Binder Spines & Labels',
#  'AMZ_P_104': 'NETGEAR AC1750 Dual Band GigabitÂ\xa0Smart WiFi Router',
#  'AMZ_P_105': 'Newell 324',
#  'AMZ_P_106': 'Microsoft Natural Keyboard Elite',
#  'AMZ_P_107': 'Southworth Structures Collection',
#  'AMZ_P_108': 'Square Ring Data Binders, Rigid 75 Pt. Covers, 11" x 14-7/8"',
#  'AMZ_P_109': 'Nortel Meridian M3904 Professional Digital phone',
#  'AMZ_P_110': 'Canon PC1080F Personal Copier',
#  'AMZ_P_111': 'Tuf-Vin Binders',
#  'AMZ_P_112': 'Sony 64GB Class 10 Micro SDHC R40 Memory Card',
#  'AMZ_P_113': 'Sharp AL-1530CS Digital Copier',
#  'AMZ_P_114': 'Wirebound Message Book, 4 per Page',
#  'AMZ_P_115': 'Bevis Round Conference Table Top, X-Base',
#  'AMZ_P_116': 'Wirebound Service Call Books, 5 1/2" x 4"',
#  'AMZ_P_117': 'Self-Adhesive Removable Labels',
#  'AMZ_P_118': 'Xerox 1908',
#  'AMZ_P_119': "O'Sullivan 4-Shelf Bookcase in Odessa Pine",
#  'AMZ_P_120': 'Novimex High-Tech Fabric Mesh Task Chair',
#  'AMZ_P_121': 'Xerox 191',
#  'AMZ_P_122': 'Bulldog Vacuum Base Pencil Sharpener',
#  'AMZ_P_123': 'Bevis Steel Folding Chairs',
#  'AMZ_P_124': 'American Pencil',
#  'AMZ_P_125': 'White Envelopes, White Envelopes with Clear Poly Window',
#  'AMZ_P_126': 'KeyTronicÂ\xa06101 Series -Â\xa0KeyboardÂ\xa0- Black',
#  'AMZ_P_127': 'Global Geo Office Task Chair, Gray',
#  'AMZ_P_128': '3M Office Air Cleaner',
#  'AMZ_P_129': 'Logitech G700s Rechargeable Gaming Mouse',
#  'AMZ_P_130': 'Acco D-Ring Binder w/DublLock',
#  'AMZ_P_131': 'Eldon Wave Desk Accessories',
#  'AMZ_P_132': 'Bush Advantage Collection Racetrack Conference Table',
#  'AMZ_P_133': 'Poly Designer Cover & Back',
#  'AMZ_P_134': 'Premier Electric Letter Opener',
#  'AMZ_P_135': 'Fellowes Premier Superior Surge Suppressor, 10-Outlet, With Phone and Remote',
#  'AMZ_P_136': 'SAFCO Boltless Steel Shelving',
#  'AMZ_P_137': 'Sauder Mission Library with Doors, Fruitwood Finish',
#  'AMZ_P_138': 'Samsung Galaxy Note 3',
#  'AMZ_P_139': 'Decoflex Hanging Personal Folder File, Blue',
#  'AMZ_P_140': 'Recycled Desk Saver Line "While You Were Out" Book, 5 1/2" X 4"',
#  'AMZ_P_141': 'Xerox 1912',
#  'AMZ_P_142': 'Cisco SPA525G2 IP Phone - Wireless',
#  'AMZ_P_143': 'ImationÂ\xa0USB 2.0 SwivelÂ\xa0Flash DriveÂ\xa0USBÂ\xa0flash driveÂ\xa0- 4 GB - Pink',
#  'AMZ_P_144': 'Alphabetical Labels for Top Tab Filing',
#  'AMZ_P_145': "O'Sullivan Living Dimensions 2-Shelf Bookcases",
#  'AMZ_P_146': 'iHome FM Clock Radio with Lightning Dock',
#  'AMZ_P_147': 'Sony Micro Vault Click 8 GB USB 2.0 Flash Drive',
#  'AMZ_P_148': 'Clear Mylar Reinforcing Strips',
#  'AMZ_P_149': 'Howard Miller 14-1/2" Diameter Chrome Round Wall Clock',
#  'AMZ_P_150': 'DMI Arturo Collection Mission-style Design Wood Chair',
#  'AMZ_P_151': 'Deflect-O Glasstique Clear Desk Accessories',
#  'AMZ_P_152': 'Vinyl Sectional Post Binders',
#  'AMZ_P_153': 'GBC Standard Therm-A-Bind Covers',
#  'AMZ_P_154': 'Global Troy Executive Leather Low-Back Tilter',
#  'AMZ_P_155': 'Storex Flexible Poly Binders with Double Pockets',
#  'AMZ_P_156': 'White Dual Perf Computer Printout Paper, 2700 Sheets, 1 Part, Heavyweight, 20 lbs., 14 7/8 x 11',
#  'AMZ_P_157': 'Newell 327',
#  'AMZ_P_158': 'Newell 317',
#  'AMZ_P_159': 'Canon Image Class D660 Copier',
#  'AMZ_P_160': 'Advantus Rolling Storage Box',
#  'AMZ_P_161': 'Great White Multi-Use Recycled Paper (20Lb. and 84 Bright)',
#  'AMZ_P_162': 'Tennsco Single-Tier Lockers',
#  'AMZ_P_163': 'Motorola HK250 Universal Bluetooth Headset',
#  'AMZ_P_164': 'ImationÂ\xa016GB Mini TravelDrive USB 2.0Â\xa0Flash Drive',
#  'AMZ_P_165': 'Safco Contoured Stacking Chairs',
#  'AMZ_P_166': 'Tenex Chairmats For Use With Carpeted Floors',
#  'AMZ_P_167': 'Sterilite Officeware Hinged File Box',
#  'AMZ_P_168': 'LG Electronics Tone+ HBS-730 Bluetooth Headset',
#  'AMZ_P_169': 'HON 5400 Series Task Chairs for Big and Tall',
#  'AMZ_P_170': 'Tennsco 16-Compartment Lockers with Coat Rack',
#  'AMZ_P_171': 'Avery 473',
#  'AMZ_P_172': 'Bretford Â“Just In TimeÂ” Height-Adjustable Multi-Task Work Tables',
#  'AMZ_P_173': 'Xerox 226',
#  'AMZ_P_174': 'Coloredge Poster Frame',
#  'AMZ_P_175': 'GBC Prepunched Paper, 19-Hole, for Binding Systems, 24-lb',
#  'AMZ_P_176': 'Alliance Big Bands Rubber Bands, 12/Pack',
#  'AMZ_P_177': 'Cisco SPA301',
#  'AMZ_P_178': 'Personal Creations Ink Jet Cards and Labels',
#  'AMZ_P_179': 'GBC White Gloss Covers, Plain Front',
#  'AMZ_P_180': 'Xerox 222',
#  'AMZ_P_181': 'Hon Every-Day Series Multi-Task Chairs',
#  'AMZ_P_182': 'Newell 332',
#  'AMZ_P_183': 'Rediform S.O.S. Phone Message Books',
#  'AMZ_P_184': 'Acme Value Line Scissors',
#  'AMZ_P_185': 'Martin-Yale Premier Letter Opener',
#  'AMZ_P_186': 'GE 30524EE4',
#  'AMZ_P_187': 'AT&T SB67148 SynJ',
#  'AMZ_P_188': 'Fellowes Basic Home/Office Series Surge Protectors',
#  'AMZ_P_189': 'Recycled Pressboard Report Cover with Reinforced Top Hinge',
#  'AMZ_P_190': 'i.Sound Portable Power - 8000 mAh',
#  'AMZ_P_191': 'Xerox 225',
#  'AMZ_P_192': 'Xerox 1894',
#  'AMZ_P_193': 'Fellowes Superior 10 Outlet Split Surge Protector',
#  'AMZ_P_194': 'AT&T 1070 Corded Phone',
#  'AMZ_P_195': 'Dana Halogen Swing-Arm Architect Lamp',
#  'AMZ_P_196': 'Belkin Premiere Surge Master II 8-outlet surge protector',
#  'AMZ_P_197': 'Acco Pressboard Covers with Storage Hooks, 9 1/2" x 11", Executive Red',
#  'AMZ_P_198': 'Tennsco Regal Shelving Units',
#  'AMZ_P_199': 'ImationÂ\xa032GB Pocket Pro USB 3.0Â\xa0Flash DriveÂ\xa0- 32 GB - Black - 1 P ...',
#  'AMZ_P_200': 'Jabra SPEAK 410',
#  'AMZ_P_201': 'Premium Transparent Presentation Covers by GBC',
#  'AMZ_P_202': 'Tripp Lite TLP810NET Broadband Surge for Modem/Fax',
#  'AMZ_P_203': 'Luxo Professional Fluorescent Magnifier Lamp with Clamp-Mount Base',
#  'AMZ_P_204': 'Wilson Jones Turn Tabs Binder Tool for Ring Binders',
#  'AMZ_P_205': 'Economy Rollaway Files',
#  'AMZ_P_206': 'Avery 480',
#  'AMZ_P_207': 'Belkin F9H710-06 7 Outlet SurgeMaster Surge Protector',
#  'AMZ_P_208': '3M Hangers With Command Adhesive',
#  'AMZ_P_209': 'AT&T TR1909W',
#  'AMZ_P_210': 'First Data FD10 PIN Pad',
#  'AMZ_P_211': 'Imation Bio 8GB USBÂ\xa0Flash Drive ImationÂ\xa0Corp',
#  'AMZ_P_212': 'Xerox 1977',
#  'AMZ_P_213': 'Tenex "The Solids" Textured Chair Mats',
#  'AMZ_P_214': 'Laminate Occasional Tables',
#  'AMZ_P_215': 'Cardinal Holdit Business Card Pockets',
#  'AMZ_P_216': 'Aluminum Document Frame',
#  'AMZ_P_217': 'Tops Green Bar Computer Printout Paper',
#  'AMZ_P_218': 'Carina Double Wide Media Storage Towers in Natural & Black',
#  'AMZ_P_219': 'LogitechÂ\xa0Illuminated - Keyboard',
#  'AMZ_P_220': 'Wilson Jones Century Plastic Molded Ring Binders',
#  'AMZ_P_221': 'Wilson Jones Leather-Like Binders with DublLock Round Rings',
#  'AMZ_P_222': "O'Sullivan Cherrywood Estates Traditional Bookcase",
#  'AMZ_P_223': 'Acco Translucent Poly Ring Binders',
#  'AMZ_P_224': 'Logitech Wireless Touch Keyboard K400',
#  'AMZ_P_225': 'KI Conference Tables',
#  'AMZ_P_226': 'Fellowes Officeware Wire Shelving',
#  'AMZ_P_227': 'Hewlett Packard 610 Color Digital Copier / Printer',
#  'AMZ_P_228': '12-1/2 Diameter Round Wall Clock',
#  'AMZ_P_229': 'Hon GuestStacker Chair',
#  'AMZ_P_230': 'Xerox 1974',
#  'AMZ_P_231': 'Xerox 1927',
#  'AMZ_P_232': 'Heavy-Duty E-Z-D Binders',
#  'AMZ_P_233': 'Lifetime Advantage Folding Chairs, 4/Carton',
#  'AMZ_P_234': 'Avery 499',
#  'AMZ_P_235': 'Situations Contoured Folding Chairs, 4/Set',
#  'AMZ_P_236': 'Executive Impressions 14" Contract Wall Clock',
#  'AMZ_P_237': 'Logitech Mobile Speakerphone P710e -Â\xa0speaker phone',
#  'AMZ_P_238': 'Eldon Stackable Tray, Side-Load, Legal, Smoke',
#  'AMZ_P_239': 'Model L Table or Wall-Mount Pencil Sharpener',
#  'AMZ_P_240': 'ClearOne CHATAttach 160 -Â\xa0speaker phone',
#  'AMZ_P_241': 'Newell 32',
#  'AMZ_P_242': 'Belkin F9G930V10-GRY 9 Outlet Surge',
#  'AMZ_P_243': 'Sony 16GB Class 10 Micro SDHC R40 Memory Card',
#  'AMZ_P_244': 'Razer Tiamat Over Ear 7.1 Surround Sound PC Gaming Headset',
#  'AMZ_P_245': 'Kingston Digital DataTraveler 32GB USB 2.0',
#  'AMZ_P_246': 'Sony Micro Vault Click 16 GB USB 2.0 Flash Drive',
#  'AMZ_P_247': 'Fellowes Binding Cases',
#  'AMZ_P_248': 'Ibico Plastic and Wire Spiral Binding Combs',
#  'AMZ_P_249': 'Acme Preferred Stainless Steel Scissors',
#  'AMZ_P_250': 'Avery 486',
#  'AMZ_P_251': 'DIXON Oriole Pencils',
#  'AMZ_P_252': 'Xerox 202',
#  'AMZ_P_253': 'Deluxe Chalkboard Eraser Cleaner',
#  'AMZ_P_254': 'Binney & Smith Crayola Metallic Crayons, 16-Color Pack',
#  'AMZ_P_255': 'Fellowes Black Plastic Comb Bindings',
#  'AMZ_P_256': 'Eldon Shelf Savers Cubes and Bins',
#  'AMZ_P_257': 'Xerox 1987',
#  'AMZ_P_258': 'File Shuttle I and Handi-File',
#  'AMZ_P_259': 'Binding Machine Supplies',
#  'AMZ_P_260': 'Xerox 1923',
#  'AMZ_P_261': 'Fellowes Neat Ideas Storage Cubes',
#  'AMZ_P_262': 'Xerox 1931',
#  'AMZ_P_263': 'Xerox 213',
#  'AMZ_P_264': 'Fellowes 8 Outlet Superior Workstation Surge Protector w/o Phone/Fax/Modem Protection',
#  'AMZ_P_265': 'Message Book, Standard Line "While You Were Out", 5 1/2" X 4", 200 Sets/Book',
#  'AMZ_P_266': 'Acco Pressboard Covers with Storage Hooks, 14 7/8" x 11", Dark Blue',
#  'AMZ_P_267': 'Standard Rollaway File with Lock',
#  'AMZ_P_268': 'Avery Trapezoid Extra Heavy Duty 4" Binders',
#  'AMZ_P_269': 'Bevis Boat-Shaped Conference Table',
#  'AMZ_P_270': 'Logitech B530 USBÂ\xa0HeadsetÂ\xa0-Â\xa0headsetÂ\xa0- Full size, Binaural',
#  'AMZ_P_271': 'Avery Durable Slant Ring Binders',
#  'AMZ_P_272': 'Universal Ultra Bright White Copier/Laser Paper, 8 1/2" x 11", Ream',
#  'AMZ_P_273': 'Luxo Professional Combination Clamp-On Lamps',
#  'AMZ_P_274': 'White Business Envelopes with Contemporary Seam, Recycled White Business Envelopes',
#  'AMZ_P_275': 'Wilson Jones Easy Flow II Sheet Lifters',
#  'AMZ_P_276': 'BIC Brite Liner Grip Highlighters, Assorted, 5/Pack',
#  'AMZ_P_277': 'Samsung Galaxy S III - 16GB - pebble blue (T-Mobile)',
#  'AMZ_P_278': 'Global Airflow Leather Mesh Back Chair, Black',
#  'AMZ_P_279': 'Advantus SlideClip Paper Clips',
#  'AMZ_P_280': 'Xerox 1979',
#  'AMZ_P_281': 'Boston 16801 Nautilus Battery Pencil Sharpener',
#  'AMZ_P_282': 'Fellowes Super Stor/Drawer Files',
#  'AMZ_P_283': 'Redi-Strip #10 Envelopes, 4 1/8 x 9 1/2',
#  'AMZ_P_284': 'UniKeep View Case Binders',
#  'AMZ_P_285': 'Eldon Delta Triangular Chair Mat, 52" x 58", Clear',
#  'AMZ_P_286': 'Howard Miller 13-3/4" Diameter Brushed Chrome Round Wall Clock',
#  'AMZ_P_287': 'Project Tote Personal File',
#  'AMZ_P_288': 'Bevis 36 x 72 Conference Tables',
#  'AMZ_P_289': 'Enermax Acrylux Wireless Keyboard',
#  'AMZ_P_290': 'GBC Plastic Binding Combs',
#  'AMZ_P_291': 'Aluminum Screw Posts',
#  'AMZ_P_292': 'Plantronics HL10 Handset Lifter',
#  'AMZ_P_293': 'Logitech Wireless Performance Mouse MX for PC and Mac',
#  'AMZ_P_294': 'Avery Hole Reinforcements',
#  'AMZ_P_295': 'Wilson Jones Ledger-Size, Piano-Hinge Binder, 2", Blue',
#  'AMZ_P_296': "Global Value Mid-Back Manager's Chair, Gray",
#  'AMZ_P_297': 'Newell 333',
#  'AMZ_P_298': 'Xerox 1881',
#  'AMZ_P_299': 'Avery Durable Slant Ring Binders With Label Holder',
#  'AMZ_P_300': 'Round Ring Binders',
#  'AMZ_P_301': 'Micropad Numeric Keypads',
#  'AMZ_P_302': 'Belkin 8 Outlet SurgeMaster II Gold Surge Protector',
#  'AMZ_P_303': 'Avery Printable Repositionable Plastic Tabs',
#  'AMZ_P_304': 'Nokia Lumia 521 (T-Mobile)',
#  'AMZ_P_305': 'Avery 488',
#  'AMZ_P_306': 'Stanley Contemporary Battery Pencil Sharpeners',
#  'AMZ_P_307': 'AT&T 1080 Corded phone',
#  'AMZ_P_308': 'Hon 4060 Series Tables',
#  'AMZ_P_309': 'Newell 326',
#  'AMZ_P_310': 'GE General Purpose, Extra Long Life, Showcase & Floodlight Incandescent Bulbs',
#  'AMZ_P_311': 'Logitech ClearChat Comfort/USB Headset H390',
#  'AMZ_P_312': 'Newell 346',
#  'AMZ_P_313': 'Rediform Wirebound "Phone Memo" Message Book, 11 x 5-3/4',
#  'AMZ_P_314': 'Bush Saratoga Collection 5-Shelf Bookcase, Hanover Cherry, *Special Order',
#  'AMZ_P_315': 'Stockwell Push Pins',
#  'AMZ_P_316': 'Xerox 223',
#  'AMZ_P_317': 'Star Micronics TSP800 TSP847IIU Receipt Printer',
#  'AMZ_P_318': 'Fellowes Mobile File Cart, Black',
#  'AMZ_P_319': 'Crayola Anti Dust Chalk, 12/Pack',
#  'AMZ_P_320': "Lock-Up Easel 'Spel-Binder'",
#  'AMZ_P_321': 'Hon Deluxe Fabric Upholstered Stacking Chairs',
#  'AMZ_P_322': 'BOSTON Model 1800 Electric Pencil Sharpeners, Putty/Woodgrain',
#  'AMZ_P_323': 'ACCOHIDE Binder by Acco',
#  'AMZ_P_324': 'Peel & Stick Add-On Corner Pockets',
#  'AMZ_P_325': 'Carina 42"Hx23 3/4"W Media Storage Unit',
#  'AMZ_P_326': 'Xerox 220',
#  'AMZ_P_327': 'Recycled Data-Pak for Archival Bound Computer Printouts, 12-1/2 x 12-1/2 x 16',
#  'AMZ_P_328': 'Kensington 6 Outlet Guardian Standard Surge Protector',
#  'AMZ_P_329': 'Toshiba IPT2010-SD IPÂ\xa0Telephone',
#  'AMZ_P_330': 'GuestStacker Chair with Chrome Finish Legs',
#  'AMZ_P_331': 'Xerox 1924',
#  'AMZ_P_332': 'Hon 4700 Series Mobuis Mid-Back Task Chairs with Adjustable Arms',
#  'AMZ_P_333': 'Sauder Facets Collection Locker/File Cabinet, Sky Alder Finish',
#  'AMZ_P_334': 'Fellowes Strictly Business Drawer File, Letter/Legal Size',
#  'AMZ_P_335': 'GE DSL Phone Line Filter',
#  'AMZ_P_336': '#10- 4 1/8" x 9 1/2" Security-Tint Envelopes',
#  'AMZ_P_337': 'Dax Clear Box Frame',
#  'AMZ_P_338': 'SANFORD Liquid Accent Tank-Style Highlighters',
#  'AMZ_P_339': 'Eldon Image Series Desk Accessories, Ebony',
#  'AMZ_P_340': 'Sanford 52201 APSCO Electric Pencil Sharpener',
#  'AMZ_P_341': 'Hon Non-Folding Utility Tables',
#  'AMZ_P_342': 'Bretford Rectangular Conference Table Tops',
#  'AMZ_P_343': 'Bestar Classic Bookcase',
#  'AMZ_P_344': 'Pencil and Crayon Sharpener',
#  'AMZ_P_345': 'Letter Size Cart',
#  'AMZ_P_346': 'ACCOHIDE 3-Ring Binder, Blue, 1"',
#  'AMZ_P_347': 'Xerox 1996',
#  'AMZ_P_348': 'Xerox 1973',
#  'AMZ_P_349': 'Avery 511',
#  'AMZ_P_350': 'Kensington 4 Outlet MasterPiece Compact Power Control Center',
#  'AMZ_P_351': 'Cardinal Slant-D Ring Binder, Heavy Gauge Vinyl',
#  'AMZ_P_352': 'GBC Binding covers',
#  'AMZ_P_353': 'Xerox 1898',
#  'AMZ_P_354': 'Belkin 6 Outlet Metallic Surge Strip',
#  'AMZ_P_355': 'Fellowes Bankers Box Recycled Super Stor/Drawer',
#  'AMZ_P_356': 'Hon Valutask Swivel Chairs',
#  'AMZ_P_357': 'Eureka Recycled Copy Paper 8 1/2" x 11", Ream',
#  'AMZ_P_358': 'Seth Thomas 12" Clock w/ Goldtone Case',
#  'AMZ_P_359': 'Panasonic KP-310 Heavy-Duty Electric Pencil Sharpener',
#  'AMZ_P_360': 'Wilson Jones Legal Size Ring Binders',
#  'AMZ_P_361': 'Westinghouse Clip-On Gooseneck Lamps',
#  'AMZ_P_362': 'Motorola L804',
#  'AMZ_P_363': 'Things To Do Today Pad',
#  'AMZ_P_364': 'Leather Task Chair, Black',
#  'AMZ_P_365': 'Cardinal EasyOpen D-Ring Binders',
#  'AMZ_P_366': 'DYMO CardScan Personal V9 Business Card Scanner',
#  'AMZ_P_367': 'Case Logic 2.4GHz Wireless Keyboard',
#  'AMZ_P_368': 'Hon 2090 Â“Pillow SoftÂ” Series Mid Back Swivel/Tilt Chairs',
#  'AMZ_P_369': 'Deflect-o SuperTray Unbreakable Stackable Tray, Letter, Black',
#  'AMZ_P_370': 'Atlantic Metals Mobile 4-Shelf Bookcases, Custom Colors',
#  'AMZ_P_371': 'Dixon My First Ticonderoga Pencil, #2',
#  'AMZ_P_372': 'Avery 490',
#  'AMZ_P_373': 'Pressboard Data Binder, Crimson, 12" X 8 1/2"',
#  'AMZ_P_374': 'Lesro Round Back Collection Coffee Table, End Table',
#  'AMZ_P_375': 'Hoover WindTunnel Plus Canister Vacuum',
#  'AMZ_P_376': 'Xerox 1934',
#  'AMZ_P_377': 'Newell 329',
#  'AMZ_P_378': 'Panasonic KX T7731-B Digital phone',
#  'AMZ_P_379': 'Safco Wire Cube Shelving System, For Use as 4 or 5 14" Cubes, Black',
#  'AMZ_P_380': 'Ibico Standard Transparent Covers',
#  'AMZ_P_381': 'Logitech G13 Programmable Gameboard with LCD Display',
#  'AMZ_P_382': 'DAX Executive Solid Wood Document Frame, Desktop or Hang, Mahogany, 5 x 7',
#  'AMZ_P_383': 'Petty Cash Envelope',
#  'AMZ_P_384': 'GBC VeloBinder Electric Binding Machine',
#  'AMZ_P_385': "3M Replacement Filter for Office Air Cleaner for 20' x 33' Room",
#  'AMZ_P_386': '2300 Heavy-Duty Transfer File Systems by Perma',
#  'AMZ_P_387': 'Samsung Rugby III',
#  'AMZ_P_388': 'Prestige Round Ring Binders',
#  'AMZ_P_389': 'Acco Four Pocket Poly Ring Binder with Label Holder, Smoke, 1"',
#  'AMZ_P_390': 'Avery 4027 File Folder Labels for Dot Matrix Printers, 5000 Labels per Box, White',
#  'AMZ_P_391': 'Strathmore Photo Mount Cards',
#  'AMZ_P_392': 'Deluxe Heavy-Duty Vinyl Round Ring Binder',
#  'AMZ_P_393': 'OtterBox Defender Series Case - iPhone 5c',
#  'AMZ_P_394': 'Wilson Jones DublLock D-Ring Binders',
#  'AMZ_P_395': 'Wilson Jones Heavy-Duty Casebound Ring Binders with Metal Hinges',
#  'AMZ_P_396': 'SanDisk Ultra 64 GB MicroSDHC Class 10 Memory Card',
#  'AMZ_P_397': 'Avery 482',
#  'AMZ_P_398': 'Square Credit Card Reader',
#  'AMZ_P_399': 'Xerox 192',
#  'AMZ_P_400': 'HP Office Recycled Paper (20Lb. and 87 Bright)',
#  'AMZ_P_401': 'X-Rack File for Hanging Folders',
#  'AMZ_P_402': 'WD My Passport Ultra 500GB Portable External Hard Drive',
#  'AMZ_P_403': 'Cisco IP Phone 7961G-GE VoIP phone',
#  'AMZ_P_404': 'Logitech Trackman Marble Mouse',
#  'AMZ_P_405': 'Magna Visual Magnetic Picture Hangers',
#  'AMZ_P_406': 'Avery Durable Plastic 1" Binders',
#  'AMZ_P_407': 'iKross Bluetooth Portable Keyboard + Cell Phone Stand Holder + Brush for Apple iPhone 5S 5C 5, 4S 4',
#  'AMZ_P_408': 'DAX Value U-Channel Document Frames, Easel Back',
#  'AMZ_P_409': 'Prang Dustless Chalk Sticks',
#  'AMZ_P_410': 'Hon 2111 Invitation Series Corner Table',
#  'AMZ_P_411': 'Eldon Image Series Desk Accessories, Burgundy',
#  'AMZ_P_412': 'Boston Heavy-Duty Trimline Electric Pencil Sharpeners',
#  'AMZ_P_413': '4009 Highlighters by Sanford',
#  'AMZ_P_414': 'Avery Durable Poly Binders',
#  'AMZ_P_415': 'Howard Miller 13" Diameter Pewter Finish Round Wall Clock',
#  'AMZ_P_416': 'Xerox 1970',
#  'AMZ_P_417': 'Xerox 1960',
#  'AMZ_P_418': 'Belkin 19" Vented Equipment Shelf, Black',
#  'AMZ_P_419': 'Neat Ideas Personal Hanging Folder Files, Black',
#  'AMZ_P_420': 'OIC Bulk Pack Metal Binder Clips',
#  'AMZ_P_421': 'Bush Andora Bookcase, Maple/Graphite Gray Finish',
#  'AMZ_P_422': 'GBC Recycled Grain Textured Covers',
#  'AMZ_P_423': 'Newell 310',
#  'AMZ_P_424': 'KI Adjustable-Height Table',
#  'AMZ_P_425': 'Acco Pressboard Covers with Storage Hooks, 14 7/8" x 11", Light Blue',
#  'AMZ_P_426': 'Avery 518',
#  'AMZ_P_427': 'Wireless Extenders zBoost YX545 SOHO Signal Booster',
#  'AMZ_P_428': 'Novimex Swivel Fabric Task Chair',
#  'AMZ_P_429': 'Pastel Pink Envelopes',
#  'AMZ_P_430': 'Belkin F8E887 USB Wired Ergonomic Keyboard',
#  'AMZ_P_431': 'Pyle PRT45 Retro HomeÂ\xa0Telephone',
#  'AMZ_P_432': 'Spiral Phone Message Books with Labels by Adams',
#  'AMZ_P_433': 'PowerGen Dual USB Car Charger',
#  'AMZ_P_434': 'Newell 307',
#  'AMZ_P_435': 'Panasonic KP-4ABK Battery-Operated Pencil Sharpener',
#  'AMZ_P_436': 'Angle-D Binders with Locking Rings, Label Holders',
#  'AMZ_P_437': 'Adams Telephone Message Book W/Dividers/Space For Phone Numbers, 5 1/4"X8 1/2", 200/Messages',
#  'AMZ_P_438': 'Avery Binder Labels',
#  'AMZ_P_439': 'Sauder Inglewood Library Bookcases',
#  'AMZ_P_440': 'VTech DS6151',
#  'AMZ_P_441': 'GE 48" Fluorescent Tube, Cool White Energy Saver, 34 Watts, 30/Box',
#  'AMZ_P_442': 'Dot Matrix Printer Tape Reel Labels, White, 5000/Box',
#  'AMZ_P_443': 'Micro Innovations USB RF Wireless Keyboard with Mouse',
#  'AMZ_P_444': 'ShoreTel ShorePhone IP 230 VoIP phone',
#  'AMZ_P_445': 'Plantronics Savi W720 Multi-Device Wireless Headset System',
#  'AMZ_P_446': 'Xerox 2',
#  'AMZ_P_447': 'Office Impressions Heavy Duty Welded Shelving & Multimedia Storage Drawers',
#  'AMZ_P_448': 'Jawbone MINI JAMBOX Wireless Bluetooth Speaker',
#  'AMZ_P_449': 'Deluxe Rollaway Locking File with Drawer',
#  'AMZ_P_450': 'Canon PC940 Copier',
#  'AMZ_P_451': 'Multicolor Computer Printout Paper',
#  'AMZ_P_452': 'Xerox 1940',
#  'AMZ_P_453': 'Xerox 1986',
#  'AMZ_P_454': 'Eldon Portable Mobile Manager',
#  'AMZ_P_455': 'Binder Clips by OIC',
#  'AMZ_P_456': 'Wilson Jones 1" Hanging DublLock Ring Binders',
#  'AMZ_P_457': 'Fellowes Bankers Box Stor/Drawer Steel Plus',
#  'AMZ_P_458': 'RCA Visys Integrated PBX 8-Line Router',
#  'AMZ_P_459': 'GBC Velobind Prepunched Cover Sets, Regency Series',
#  'AMZ_P_460': 'Cardinal Slant-D Ring Binders',
#  'AMZ_P_461': 'Home/Office Personal File Carts',
#  'AMZ_P_462': 'Universal Premium White Copier/Laser Paper (20Lb. and 87 Bright)',
#  'AMZ_P_463': 'Xerox 1887',
#  'AMZ_P_464': 'C-Line Magnetic Cubicle Keepers, Clear Polypropylene',
#  'AMZ_P_465': 'Avery 497',
#  'AMZ_P_466': 'GBC Standard Recycled Report Covers, Clear Plastic Sheets',
#  'AMZ_P_467': 'Avery 500',
#  'AMZ_P_468': 'Geemarc AmpliPOWER60',
#  'AMZ_P_469': '"While you Were Out" Message Book, One Form per Page',
#  'AMZ_P_470': 'Global Leather Task Chair, Black',
#  'AMZ_P_471': 'Acco 7-Outlet Masterpiece Power Center, Wihtout Fax/Phone Line Protection',
#  'AMZ_P_472': "O'Sullivan Manor Hill 2-Door Library in Brianna Oak",
#  'AMZ_P_473': 'Kingston Digital DataTraveler 16GB USB 2.0',
#  'AMZ_P_474': 'TRENDnet 56K USB 2.0 Phone, Internet and Fax Modem',
#  'AMZ_P_475': 'Avery 494',
#  'AMZ_P_476': 'Xerox 1962',
#  'AMZ_P_477': 'Sauder Camden County Barrister Bookcase, Planked Cherry Finish',
#  'AMZ_P_478': 'DXL Angle-View Binders with Locking Rings, Black',
#  'AMZ_P_479': 'Sauder Camden County Collection Libraries, Planked Cherry Finish',
#  'AMZ_P_480': 'Xerox 1919',
#  'AMZ_P_481': 'Prang Colored Pencils',
#  'AMZ_P_482': 'Howard Miller 11-1/2" Diameter Grantwood Wall Clock',
#  'AMZ_P_483': 'Samsung Galaxy Note 2',
#  'AMZ_P_484': 'SanDisk Cruzer 64 GB USB Flash Drive',
#  'AMZ_P_485': 'Avery 501',
#  'AMZ_P_486': 'Binney & Smith Crayola Metallic Colored Pencils, 8-Color Set',
#  'AMZ_P_487': 'Avery 513',
#  'AMZ_P_488': 'Avery 3 1/2" Diskette Storage Pages, 10/Pack',
#  'AMZ_P_489': 'Seth Thomas 14" Day/Date Wall Clock',
#  'AMZ_P_490': 'Executive Impressions 8-1/2" Career Panel/Partition Cubicle Clock',
#  'AMZ_P_491': 'Howard Miller 12" Round Wall Clock',
#  'AMZ_P_492': 'Newell 334',
#  'AMZ_P_493': 'Hon 30" x 60" Table with Locking Drawer',
#  'AMZ_P_494': 'Safco Drafting Table',
#  'AMZ_P_495': 'Global High-Back Leather Tilter, Burgundy',
#  'AMZ_P_496': 'Ultra Door Pull Handle',
#  'AMZ_P_497': 'Xerox 1972',
#  'AMZ_P_498': 'Avery Hi-Liter Fluorescent Desk Style Markers',
#  'AMZ_P_499': 'IBM Multi-Purpose Copy Paper, 8 1/2 x 11", Case',
#  'AMZ_P_500': 'Ibico Hi-Tech Manual Binding System',
#  'AMZ_P_501': 'Xerox 218',
#  'AMZ_P_502': 'Global Comet Stacking Armless Chair',
#  'AMZ_P_503': 'Memorex Froggy Flash Drive 8 GB',
#  'AMZ_P_504': 'Hand-Finished Solid Wood Document Frame',
#  'AMZ_P_505': 'Avaya 4621SW VoIP phone',
#  'AMZ_P_506': 'Eaton Premium Continuous-Feed Paper, 25% Cotton, Letter Size, White, 1000 Shts/Box',
#  'AMZ_P_507': 'Xerox 214',
#  'AMZ_P_508': 'Safco Commercial Shelving',
#  'AMZ_P_509': 'Mitel MiVoice 5330e IP Phone',
#  'AMZ_P_510': 'Motorola Moto X',
#  'AMZ_P_511': 'Tops White Computer Printout Paper',
#  'AMZ_P_512': 'Enermax Briskie RF Wireless Keyboard and Mouse Combo',
#  'AMZ_P_513': 'Ultra Door Push Plate',
#  'AMZ_P_514': 'GBC Twin Loop Wire Binding Elements',
#  'AMZ_P_515': 'Perma STOR-ALL Hanging File Box, 13 1/8"W x 12 1/4"D x 10 1/2"H',
#  'AMZ_P_516': 'SAFCO Arco Folding Chair',
#  'AMZ_P_517': 'Newell 321',
#  'AMZ_P_518': 'Fellowes Personal Hanging Folder Files, Navy',
#  'AMZ_P_519': 'Wirebound Message Books, Four 2 3/4 x 5 White Forms per Page',
#  'AMZ_P_520': 'Eldon Spacemaker Box, Quick-Snap Lid, Clear',
#  'AMZ_P_521': 'Plymouth Boxed Rubber Bands by Plymouth',
#  'AMZ_P_522': 'Dixon Ticonderoga Erasable Colored Pencil Set, 12-Color',
#  'AMZ_P_523': 'GBC Imprintable Covers',
#  'AMZ_P_524': 'Acme Elite Stainless Steel Scissors',
#  'AMZ_P_525': 'Wirebound Message Books, 5-1/2 x 4 Forms, 2 or 4 Forms per Page',
#  'AMZ_P_526': 'GBC Recycled Regency Composition Covers',
#  'AMZ_P_527': 'Safco Value Mate Series Steel Bookcases, Baked Enamel Finish on Steel, Gray',
#  'AMZ_P_528': 'Xerox 1922',
#  'AMZ_P_529': 'Flat Face Poster Frame',
#  'AMZ_P_530': 'GBC Personal VeloBind Strips',
#  'AMZ_P_531': 'Letter/Legal File Tote with Clear Snap-On Lid, Black Granite',
#  'AMZ_P_532': 'Avery Framed View Binder, EZD Ring (Locking), Navy, 1 1/2"',
#  'AMZ_P_533': 'Xerox 1952',
#  'AMZ_P_534': 'Fellowes Twister Kit, Gray/Clear, 3/pkg',
#  'AMZ_P_535': 'Novimex Fabric Task Chair',
#  'AMZ_P_536': 'MaxellÂ\xa0LTO Ultrium - 800 GB',
#  'AMZ_P_537': 'Newell 325',
#  'AMZ_P_538': 'Plantronics Audio 478 Stereo USB Headset',
#  'AMZ_P_539': 'Hon 94000 Series Round Tables',
#  'AMZ_P_540': 'Newell 3-Hole Punched Plastic Slotted Magazine Holders for Binders',
#  'AMZ_P_541': 'Anker Ultra-Slim Mini Bluetooth 3.0 Wireless Keyboard',
#  'AMZ_P_542': 'Plantronics CS 50-USB -Â\xa0headsetÂ\xa0- Convertible, Monaural',
#  'AMZ_P_543': 'Floodlight Indoor Halogen Bulbs, 1 Bulb per Pack, 60 Watts',
#  'AMZ_P_544': 'Computer Printout Paper with Letter-Trim Perforations',
#  'AMZ_P_545': 'ClearSounds CSC500 Amplified Spirit Phone Corded phone',
#  'AMZ_P_546': 'Ampad Phone Message Book, Recycled, 400 Message Capacity, 5 Â¾Â” x 11Â”',
#  'AMZ_P_547': 'Avery 507',
#  'AMZ_P_548': 'Hanging Personal Folder File',
#  'AMZ_P_549': 'Logitech Wireless Marathon Mouse M705',
#  'AMZ_P_550': 'Tennsco 6- and 18-Compartment Lockers',
#  'AMZ_P_551': 'BOSTON Ranger #55 Pencil Sharpener, Black',
#  'AMZ_P_552': 'Office Star - Ergonomically Designed Knee Chair',
#  'AMZ_P_553': 'GBC DocuBind P100 Manual Binding Machine',
#  'AMZ_P_554': 'Newell 308',
#  'AMZ_P_555': "Global Fabric Manager's Chair, Dark Gray",
#  'AMZ_P_556': 'Acme Tagit Stainless Steel Antibacterial Scissors',
#  'AMZ_P_557': 'Polycom SoundStation2 EX ConferenceÂ\xa0phone',
#  'AMZ_P_558': 'Mobile Personal File Cube',
#  'AMZ_P_559': 'DMI Eclipse Executive Suite Bookcases',
#  'AMZ_P_560': 'Xerox Color Copier Paper, 11" x 17", Ream',
#  'AMZ_P_561': 'GBC DocuBind TL200 Manual Binding Machine',
#  'AMZ_P_562': 'Eldon Advantage Chair Mats for Low to Medium Pile Carpets',
#  'AMZ_P_563': 'Panasonic KP-350BK Electric Pencil Sharpener with Auto Stop',
#  'AMZ_P_564': 'Wilson Jones data.warehouse D-Ring Binders with DublLock',
#  'AMZ_P_565': 'Xerox 1982',
#  'AMZ_P_566': 'Acco Data Flex Cable Posts For Top & Bottom Load Binders, 6" Capacity',
#  'AMZ_P_567': 'GBC Prestige Therm-A-Bind Covers',
#  'AMZ_P_568': 'Fellowes Mighty 8 Compact Surge Protector',
#  'AMZ_P_569': 'GBC DocuBind P50 Personal Binding Machine',
#  'AMZ_P_570': 'Holmes HEPA Air Purifier',
#  'AMZ_P_571': 'Xerox 1988',
#  'AMZ_P_572': 'Harmony HEPA Quiet Air Purifiers',
#  'AMZ_P_573': 'Acco Hanging Data Binders',
#  'AMZ_P_574': 'Howard Miller 16" Diameter Gallery Wall Clock',
#  'AMZ_P_575': "Belkin 325VA UPS Surge Protector, 6'",
#  'AMZ_P_576': 'Metal Folding Chairs, Beige, 4/Carton',
#  'AMZ_P_577': 'Zipper Ring Binder Pockets',
#  'AMZ_P_578': 'Super Decoflex Portable Personal File',
#  'AMZ_P_579': 'Wilson Electronics DB Pro Signal Booster',
#  'AMZ_P_580': 'Atlantic Metals Mobile 2-Shelf Bookcases, Custom Colors',
#  'AMZ_P_581': 'GBC DocuBind 200 Manual Binding Machine',
#  'AMZ_P_582': 'Fellowes Advanced Computer Series Surge Protectors',
#  'AMZ_P_583': 'HTC One',
#  'AMZ_P_584': 'Fiskars Home & Office Scissors',
#  'AMZ_P_585': 'Fellowes PB500 Electric Punch Plastic Comb Binding Machine with Manual Bind',
#  'AMZ_P_586': 'Avery Self-Adhesive Photo Pockets for Polaroid Photos',
#  'AMZ_P_587': 'Newell 344',
#  'AMZ_P_588': 'Advantus T-Pin Paper Clips',
#  'AMZ_P_589': "Acco Six-Outlet Power Strip, 4' Cord Length",
#  'AMZ_P_590': 'Xerox 1959',
#  'AMZ_P_591': 'Avery Durable Binders',
#  'AMZ_P_592': 'Kensington 6 Outlet MasterPiece HOMEOFFICE Power Control Center',
#  'AMZ_P_593': 'Xerox 22',
#  'AMZ_P_594': 'Holmes Odor Grabber',
#  'AMZ_P_595': 'Hon Multipurpose Stacking Arm Chairs',
#  'AMZ_P_596': 'Wirebound Message Books, Four 2 3/4" x 5" Forms per Page, 600 Sets per Book',
#  'AMZ_P_597': 'Advantus Plastic Paper Clips',
#  'AMZ_P_598': 'Logitech G19 Programmable Gaming Keyboard',
#  'AMZ_P_599': 'Xerox 1984',
#  'AMZ_P_600': 'Fellowes Bases and Tops For Staxonsteel/High-Stak Systems',
#  'AMZ_P_601': 'Deflect-o Glass Clear Studded Chair Mats',
#  'AMZ_P_602': 'Canon PC1060 Personal Laser Copier',
#  'AMZ_P_603': 'Bevis Round Conference Room Tables and Bases',
#  'AMZ_P_604': 'Global Deluxe Stacking Chair, Gray',
#  'AMZ_P_605': 'Global Super Steno Chair',
#  'AMZ_P_606': 'Newell 351',
#  'AMZ_P_607': 'Balt Solid Wood Round Tables',
#  'AMZ_P_608': 'Global Leather Executive Chair',
#  'AMZ_P_609': 'Newell 319',
#  'AMZ_P_610': 'ImationÂ\xa0SecureÂ\xa0DriveÂ\xa0+ Hardware Encrypted USBÂ\xa0flash driveÂ\xa0- 16 GB',
#  'AMZ_P_611': 'Wausau Papers Astrobrights Colored Envelopes',
#  'AMZ_P_612': 'Tennsco Lockers, Gray',
#  'AMZ_P_613': 'REDIFORM Incoming/Outgoing Call Register, 11" X 8 1/2", 100 Messages',
#  'AMZ_P_614': 'Satellite Sectional Post Binders',
#  'AMZ_P_615': 'Atlantic Metals Mobile 3-Shelf Bookcases, Custom Colors',
#  'AMZ_P_616': 'Memorex Micro Travel Drive 32 GB',
#  'AMZ_P_617': 'Lexmark S315 Color Inkjet Printer',
#  'AMZ_P_618': 'Global Leather & Oak Executive Chair, Burgundy',
#  'AMZ_P_619': 'Message Book, Phone, Wirebound Standard Line Memo, 2 3/4" X 5"',
#  'AMZ_P_620': 'Acco Smartsocket Color-Coded Six-Outlet AC Adapter Model Surge Protectors',
#  'AMZ_P_621': 'Avery Arch Ring Binders',
#  'AMZ_P_622': 'Clearsounds A400',
#  'AMZ_P_623': 'Hewlett Packard 310 Color Digital Copier',
#  'AMZ_P_624': 'Recycled Premium Regency Composition Covers',
#  'AMZ_P_625': 'Avery File Folder Labels',
#  'AMZ_P_626': 'Newell 318',
#  'AMZ_P_627': 'Square Credit Card Reader, 4 1/2" x 4 1/2" x 1", White',
#  'AMZ_P_628': 'Panasonic KX-TG9541B DECT 6.0 Digital 2-Line Expandable Cordless Phone With Digital Answering System',
#  'AMZ_P_629': 'DAX Natural Wood-Tone Poster Frame',
#  'AMZ_P_630': 'WD My Passport Ultra 2TB Portable External Hard Drive',
#  'AMZ_P_631': 'Panasonic KX MB2061 Multifunction Printer',
#  'AMZ_P_632': 'Razer Kraken 7.1 Surround Sound Over Ear USB Gaming Headset',
#  'AMZ_P_633': 'Tenex Traditional Chairmats for Medium Pile Carpet, Standard Lip, 36" x 48"',
#  'AMZ_P_634': 'Bevis Rectangular Conference Tables',
#  'AMZ_P_635': 'Geographics Note Cards, Blank, White, 8 1/2" x 11"',
#  'AMZ_P_636': '#10- 4 1/8" x 9 1/2" Recycled Envelopes',
#  'AMZ_P_637': 'Cardinal Holdit Data Disk Pockets',
#  'AMZ_P_638': 'Xerox 1896',
#  'AMZ_P_639': 'Global Deluxe High-Back Office Chair in Storm',
#  'AMZ_P_640': 'Kensington K72356US Mouse-in-a-Box USB Desktop Mouse',
#  'AMZ_P_641': 'Avery 50',
#  'AMZ_P_642': "Honeywell Enviracaire Portable HEPA Air Cleaner for 16' x 20' Room",
#  'AMZ_P_643': 'Chromcraft Bull-Nose Wood Oval Conference Tables & Bases',
#  'AMZ_P_644': 'Anker 24W Portable Micro USB Car Charger',
#  'AMZ_P_645': 'Hon Practical Foundations 30 x 60 Training Table, Light Gray/Charcoal',
#  'AMZ_P_646': 'White GlueTop Scratch Pads',
#  'AMZ_P_647': 'Cameo Buff Policy Envelopes',
#  'AMZ_P_648': 'Avery 52',
#  'AMZ_P_649': 'High Speed Automatic Electric Letter Opener',
#  'AMZ_P_650': 'Panasonic KX TS3282B Corded phone',
#  'AMZ_P_651': 'Memorex Mini Travel Drive 8 GB USB 2.0 Flash Drive',
#  'AMZ_P_652': 'Samsung Galaxy S4 Mini',
#  'AMZ_P_653': 'Xerox 1891',
#  'AMZ_P_654': "O'Sullivan Living Dimensions 3-Shelf Bookcases",
#  'AMZ_P_655': "GBC Standard Plastic Binding Systems' Combs",
#  'AMZ_P_656': 'Cisco Small Business SPA 502G VoIP phone',
#  'AMZ_P_657': 'Berol Giant Pencil Sharpener',
#  'AMZ_P_658': 'Global Stack Chair without Arms, Black',
#  'AMZ_P_659': 'Acco Pressboard Covers with Storage Hooks, 14 7/8" x 11", Executive Red',
#  'AMZ_P_660': 'Avery 498',
#  'AMZ_P_661': 'Design Ebony Sketching Pencil',
#  'AMZ_P_662': 'Eldon Simplefile Box Office',
#  'AMZ_P_663': 'Avery 517',
#  'AMZ_P_664': '24-Hour Round Wall Clock',
#  'AMZ_P_665': 'SAFCO Optional Arm Kit for Workspace Cribbage Stacking Chair',
#  'AMZ_P_666': 'Green Bar Computer Printout Paper',
#  'AMZ_P_667': 'Global Adaptabilites Bookcase, Cherry/Storm Gray Finish',
#  'AMZ_P_668': 'GBC Pre-Punched Binding Paper, Plastic, White, 8-1/2" x 11"',
#  'AMZ_P_669': 'Mini 13-1/2 Capacity Data Binder Rack, Pearl',
#  'AMZ_P_670': 'Avery 514',
#  'AMZ_P_671': 'Xerox 1888',
#  'AMZ_P_672': 'Adams "While You Were Out" Message Pads',
#  'AMZ_P_673': 'Wirebound Four 2-3/4 x 5 Forms per Page, 400 Sets per Book',
#  'AMZ_P_674': 'AT&T 17929 Lendline Telephone',
#  'AMZ_P_675': 'Contract Clock, 14", Brown',
#  'AMZ_P_676': 'Xerox 215',
#  'AMZ_P_677': 'Xerox 1885',
#  'AMZ_P_678': 'Computer Room Manger, 14"',
#  'AMZ_P_679': 'Bady BDG101FRU Card Printer',
#  'AMZ_P_680': 'Prang Drawing Pencil Set',
#  'AMZ_P_681': 'Avery 512',
#  'AMZ_P_682': 'Tenex Contemporary Contur Chairmats for Low and Medium Pile Carpet, Computer, 39" x 49"',
#  'AMZ_P_683': 'Executive Impressions 12" Wall Clock',
#  'AMZ_P_684': 'Hon Deluxe Fabric Upholstered Stacking Chairs, Squared Back',
#  'AMZ_P_685': 'Advantus Rolling Drawer Organizers',
#  'AMZ_P_686': 'Hon Olson Stacker Stools',
#  'AMZ_P_687': 'Plantronics S12 Corded Telephone Headset System',
#  'AMZ_P_688': 'Plantronics Calisto P620-M USB Wireless Speakerphone System',
#  'AMZ_P_689': 'Hoover Upright Vacuum With Dirt Cup',
#  'AMZ_P_690': 'Xerox 1903',
#  'AMZ_P_691': 'Maxell 4.7GB DVD-R 5/Pack',
#  'AMZ_P_692': 'Canvas Sectional Post Binders',
#  'AMZ_P_693': 'Advantus Map Pennant Flags and Round Head Tacks',
#  'AMZ_P_694': 'Pyle PMP37LED',
#  'AMZ_P_695': 'Lumber Crayons',
#  'AMZ_P_696': '9-3/4 Diameter Round Wall Clock',
#  'AMZ_P_697': 'Xerox 1953',
#  'AMZ_P_698': 'Xerox 228',
#  'AMZ_P_699': 'Sauder Forest Hills Library, Woodland Oak Finish',
#  'AMZ_P_700': 'Office Star - Professional Matrix Back Chair with 2-to-1 Synchro Tilt and Mesh Fabric Seat',
#  'AMZ_P_701': 'Computer Printout Index Tabs',
#  'AMZ_P_702': 'Carina Mini System Audio Rack, Model AR050B',
#  'AMZ_P_703': 'Plantronics Voyager Pro HD - Bluetooth Headset',
#  'AMZ_P_704': 'Xerox 201',
#  'AMZ_P_705': 'Ibico Plastic Spiral Binding Combs',
#  'AMZ_P_706': 'Newell 345',
#  'AMZ_P_707': 'Xerox 1951',
#  'AMZ_P_708': 'Office Star - Mesh Screen back chair with Vinyl seat',
#  'AMZ_P_709': 'Dixon Prang Watercolor Pencils, 10-Color Set with Brush',
#  'AMZ_P_710': 'Global Ergonomic Managers Chair',
#  'AMZ_P_711': 'Eldon Regeneration Recycled Desk Accessories, Smoke',
#  'AMZ_P_712': 'Global Deluxe Steno Chair',
#  'AMZ_P_713': 'Wirebound Message Books, Four 2 3/4 x 5 Forms per Page, 200 Sets per Book',
#  'AMZ_P_714': 'Dual Level, Single-Width Filing Carts',
#  'AMZ_P_715': 'Rubber Band Ball',
#  'AMZ_P_716': 'Space Solutions Commercial Steel Shelving',
#  'AMZ_P_717': 'Google Nexus 5',
#  'AMZ_P_718': "Jet-Pak Recycled Peel 'N' Seal Padded Mailers",
#  'AMZ_P_719': 'Snap-A-Way Black Print Carbonless Ruled Speed Letter, Triplicate',
#  'AMZ_P_720': 'File Shuttle II and Handi-File, Black',
#  'AMZ_P_721': 'Executive Impressions 13-1/2" Indoor/Outdoor Wall Clock',
#  'AMZ_P_722': 'Advantus Panel Wall Acrylic Frame',
#  'AMZ_P_723': 'Eldon 400 Class Desk Accessories, Black Carbon',
#  'AMZ_P_724': 'Wilson Jones Clip & Carry Folder Binder Tool for Ring Binders, Clear',
#  'AMZ_P_725': 'Memorex Micro Travel Drive 8 GB',
#  'AMZ_P_726': 'Xerox 1978',
#  'AMZ_P_727': 'Harbour Creations 67200 Series Stacking Chairs',
#  'AMZ_P_728': 'Tenex V2T-RE Standard Weight Series Chair Mat, 45" x 53", Lip 25" x 12"',
#  'AMZ_P_729': 'Cush Cases Heavy Duty Rugged Cover Case for Samsung Galaxy S5 - Purple',
#  'AMZ_P_730': 'Samsung Galaxy Mega 6.3',
#  'AMZ_P_731': 'Avery 478',
#  'AMZ_P_732': 'DAX Two-Tone Rosewood/Black Document Frame, Desktop, 5 x 7',
#  'AMZ_P_733': 'Safco Chair Connectors, 6/Carton',
#  'AMZ_P_734': 'Self-Adhesive Ring Binder Labels',
#  'AMZ_P_735': 'Chromcraft Bull-Nose Wood 48" x 96" Rectangular Conference Tables',
#  'AMZ_P_736': 'SanDisk Ultra 16 GB MicroSDHC Class 10 Memory Card',
#  'AMZ_P_737': 'Avery Heavy-Duty EZD  Binder With Locking Rings',
#  'AMZ_P_738': 'VariCap6 Expandable Binder',
#  'AMZ_P_739': "Eldon Fold 'N Roll Cart System",
#  'AMZ_P_740': 'Avery Premier Heavy-Duty Binder with Round Locking Rings',
#  'AMZ_P_741': 'Insertable Tab Post Binder Dividers',
#  'AMZ_P_742': 'Lexmark MX611dhe Monochrome Laser Printer',
#  'AMZ_P_743': 'GBC VeloBinder Manual Binding System',
#  'AMZ_P_744': 'Alliance Rubber Bands',
#  'AMZ_P_745': 'SlimView Poly Binder, 3/8"',
#  'AMZ_P_746': 'BlackBerry Q10',
#  'AMZ_P_747': 'Lesro Sheffield Collection Coffee Table, End Table, Center Table, Corner Table',
#  'AMZ_P_748': '#10 Self-Seal White Envelopes',
#  'AMZ_P_749': 'Hon Pagoda Stacking Chairs',
#  'AMZ_P_750': '36X48 HARDFLOOR CHAIRMAT',
#  'AMZ_P_751': 'Conquest 14 Commercial Heavy-Duty Upright Vacuum, Collection System, Accessory Kit',
#  'AMZ_P_752': 'Ampad #10 Peel & Seel Holiday Envelopes',
#  'AMZ_P_753': 'Linden 10" Round Wall Clock, Black',
#  'AMZ_P_754': 'Anderson Hickey Conga Table Tops & Accessories',
#  'AMZ_P_755': 'SimpliFile Personal File, Black Granite, 15w x 6-15/16d x 11-1/4h',
#  'AMZ_P_756': 'OtterBox Commuter Series Case - iPhone 5 & 5s',
#  'AMZ_P_757': 'Logitech Wireless Headset H600 Over-The-Head Design',
#  'AMZ_P_758': 'Xerox 230',
#  'AMZ_P_759': 'Recycled Steel Personal File for Hanging File Folders',
#  'AMZ_P_760': 'invisibleSHIELD by ZAGG Smudge-Free Screen Protector',
#  'AMZ_P_761': 'Okidata C331dn Printer',
#  'AMZ_P_762': 'Tyvek  Top-Opening Peel & Seel Envelopes, Plain White',
#  'AMZ_P_763': 'Office Star Flex Back Scooter Chair with White Frame',
#  'AMZ_P_764': 'Acme Rosewood Handle Letter Opener',
#  'AMZ_P_765': 'Global Leather and Oak Executive Chair, Black',
#  'AMZ_P_766': 'BIC Brite Liner Highlighters, Chisel Tip',
#  'AMZ_P_767': 'Avery 489',
#  'AMZ_P_768': 'White Computer Printout Paper by Universal',
#  'AMZ_P_769': '#10 White Business Envelopes,4 1/8 x 9 1/2',
#  'AMZ_P_770': 'Newell 34',
#  'AMZ_P_771': 'Xerox 1971',
#  'AMZ_P_772': 'Polycom CX300 Desktop Phone USB VoIP phone',
#  'AMZ_P_773': 'Atlantic Metals Mobile 5-Shelf Bookcases, Custom Colors',
#  'AMZ_P_774': 'Avery 510',
#  'AMZ_P_775': 'Wilson Jones Four-Pocket Poly Binders',
#  'AMZ_P_776': 'Accohide Poly Flexible Ring Binders',
#  'AMZ_P_777': 'Memorex Froggy Flash Drive 4 GB',
#  'AMZ_P_778': 'Southworth 100% RÃ©sumÃ© Paper, 24lb.',
#  'AMZ_P_779': 'Eldon Expressions Punched Metal & Wood Desk Accessories, Pewter & Cherry',
#  'AMZ_P_780': 'Avery White Multi-Purpose Labels',
#  'AMZ_P_781': 'Logitech G500s Laser Gaming Mouse with Adjustable Weight Tuning',
#  'AMZ_P_782': 'Avery 485',
#  'AMZ_P_783': 'Adams Telephone Message Book W/Dividers/Space For Phone Numbers, 5 1/4"X8 1/2", 300/Messages',
#  'AMZ_P_784': 'Bose SoundLink Bluetooth Speaker',
#  'AMZ_P_785': 'Letter or Legal Size Expandable Poly String Tie Envelopes',
#  'AMZ_P_786': 'Stiletto Hand Letter Openers',
#  'AMZ_P_787': 'Logitech Desktop MK120 Mouse and keyboard Combo',
#  'AMZ_P_788': 'Fellowes Bankers Box Staxonsteel Drawer File/Stacking System',
#  'AMZ_P_789': 'Col-Erase Pencils with Erasers',
#  'AMZ_P_790': 'Clarity 53712',
#  'AMZ_P_791': 'Xerox 1941',
#  'AMZ_P_792': 'APC 7 Outlet Network SurgeArrest Surge Protector',
#  'AMZ_P_793': 'Canon Imageclass D680 Copier / Fax',
#  'AMZ_P_794': 'Plantronics Voyager Pro Legend',
#  'AMZ_P_795': 'Memorex Mini Travel Drive 64 GB USB 2.0 Flash Drive',
#  'AMZ_P_796': 'Boston 19500 Mighty Mite Electric Pencil Sharpener',
#  'AMZ_P_797': 'Avery 474',
#  'AMZ_P_798': 'Newell 336',
#  'AMZ_P_799': 'Cisco 8x8 Inc. 6753i IP Business Phone System',
#  'AMZ_P_800': 'Tenex Chairmats For Use with Hard Floors',
#  'AMZ_P_801': 'Acco Flexible ACCOHIDE Square Ring Data Binder, Dark Blue, 11 1/2" X 14" 7/8"',
#  'AMZ_P_802': 'Fellowes Command Center 5-outlet power strip',
#  'AMZ_P_803': 'Avery Address/Shipping Labels for Typewriters, 4" x 2"',
#  'AMZ_P_804': '50 Colored Long Pencils',
#  'AMZ_P_805': 'Rush Hierlooms Collection 1" Thick Stackable Bookcases',
#  'AMZ_P_806': 'Sauder Facets Collection Library, Sky Alder Finish',
#  'AMZ_P_807': 'Hon Metal Bookcases, Putty',
#  'AMZ_P_808': 'Acco PRESSTEX Data Binder with Storage Hooks, Light Blue, 9 1/2" X 11"',
#  'AMZ_P_809': 'Cisco Unified IP Phone 7945G VoIP phone',
#  'AMZ_P_810': 'Strathmore Photo Frame Cards',
#  'AMZ_P_811': 'Xerox 1944',
#  'AMZ_P_812': 'Kensington 7 Outlet MasterPiece HOMEOFFICE Power Control Center',
#  'AMZ_P_813': 'Xerox 1991',
#  'AMZ_P_814': 'ImationÂ\xa0Clip USBÂ\xa0flash driveÂ\xa0- 8 GB',
#  'AMZ_P_815': 'Akro-Mils 12-Gallon Tote',
#  'AMZ_P_816': 'Tenex Traditional Chairmats for Hard Floors, Average Lip, 36" x 48"',
#  'AMZ_P_817': 'Xerox 1968',
#  'AMZ_P_818': 'GBC Wire Binding Combs',
#  'AMZ_P_819': 'GBC Recycled VeloBinder Covers',
#  'AMZ_P_820': 'Holmes Replacement Filter for HEPA Air Cleaner, Medium Room',
#  'AMZ_P_821': 'Pizazz Global Quick File',
#  'AMZ_P_822': 'KeyTronicÂ\xa0KT400U2 -Â\xa0KeyboardÂ\xa0- Black',
#  'AMZ_P_823': 'Xerox 204',
#  'AMZ_P_824': 'Chromcraft 48" x 96" Racetrack Double Pedestal Table',
#  'AMZ_P_825': 'HP Standard 104 key PS/2 Keyboard',
#  'AMZ_P_826': 'Macally Suction Cup Mount',
#  'AMZ_P_827': 'Ativa MDM8000 8-Sheet Micro-Cut Shredder',
#  'AMZ_P_828': 'Binney & Smith inkTank Desk Highlighter, Chisel Tip, Yellow, 12/Box',
#  'AMZ_P_829': 'Advantus Push Pins, Aluminum Head',
#  'AMZ_P_830': 'Ooma Telo VoIP Home Phone System',
#  'AMZ_P_831': 'Xerox 1905',
#  'AMZ_P_832': 'Cardinal HOLDit! Binder Insert Strips,Extra Strips',
#  'AMZ_P_833': 'Plantronics Audio 995 Wireless Stereo Headset',
#  'AMZ_P_834': 'Xerox 200',
#  'AMZ_P_835': 'Brites Rubber Bands, 1 1/2 oz. Box',
#  'AMZ_P_836': 'Okidata MB491 Multifunction Printer',
#  'AMZ_P_837': 'Avery Hanging File Binders',
#  'AMZ_P_838': 'While You Were Out Pads, 50 per Pad, 4 x 5 1/4, Green Cycle',
#  'AMZ_P_839': 'Kensington Orbit Wireless Mobile Trackball for PC and Mac',
#  'AMZ_P_840': 'QVS USB Car Charger 2-Port 2.1Amp for iPod/iPhone/iPad/iPad 2/iPad 3',
#  'AMZ_P_841': 'Newell 314',
#  'AMZ_P_842': 'Ibico Ibimaster 300 Manual Binding System',
#  'AMZ_P_843': 'Multi-Use Personal File Cart and Caster Set, Three Stacking Bins',
#  'AMZ_P_844': 'Fellowes Stor/Drawer Steel Plus Storage Drawers',
#  'AMZ_P_845': 'Boston Home & Office Model 2000 Electric Pencil Sharpeners',
#  'AMZ_P_846': 'Newell 31',
#  'AMZ_P_847': 'Premium Transparent Presentation Covers, No Pattern/Clear, 8 1/2" x 11"',
#  'AMZ_P_848': 'Xerox 1966',
#  'AMZ_P_849': 'Acme Kleen Earth Office Shears',
#  'AMZ_P_850': 'Elite 5" Scissors',
#  'AMZ_P_851': 'Acco PRESSTEX Data Binder with Storage Hooks, Dark Blue, 9 1/2" X 11"',
#  'AMZ_P_852': 'Samsung HM1900 Bluetooth Headset',
#  'AMZ_P_853': 'Acco Side-Punched Conventional Columnar Pads',
#  'AMZ_P_854': 'Avery 492',
#  'AMZ_P_855': 'Xerox 232',
#  'AMZ_P_856': 'Adjustable Personal File Tote',
#  'AMZ_P_857': 'Crayola Colored Pencils',
#  'AMZ_P_858': 'Manila Recycled Extra-Heavyweight Clasp Envelopes, 6" x 9"',
#  'AMZ_P_859': 'Sharp 1540cs Digital Laser Copier',
#  'AMZ_P_860': 'Eldon Regeneration Recycled Desk Accessories, Black',
#  'AMZ_P_861': 'Eldon File Chest Portable File',
#  'AMZ_P_862': 'Bush Advantage Collection Round Conference Table',
#  'AMZ_P_863': 'Verbatim Slim CD and DVD Storage Cases, 50/Pack',
#  'AMZ_P_864': 'Eldon Advantage Foldable Chair Mats for Low Pile Carpets',
#  'AMZ_P_865': 'Xerox 1964',
#  'AMZ_P_866': 'GBC DocuBind 300 Electric Binding Machine',
#  'AMZ_P_867': 'Sensible Storage WireTech Storage Systems',
#  'AMZ_P_868': 'Quartet Omega Colored Chalk, 12/Pack',
#  'AMZ_P_869': 'Advantus Panel Wall Certificate Holder - 8.5x11',
#  'AMZ_P_870': 'Rubbermaid ClusterMat Chairmats, Mat Size- 66" x 60", Lip 20" x 11" -90 Degree Angle',
#  'AMZ_P_871': 'Balt Split Level Computer Training Table',
#  'AMZ_P_872': 'Dixon Ticonderoga Core-Lock Colored Pencils',
#  'AMZ_P_873': 'Things To Do Today Spiral Book',
#  'AMZ_P_874': 'Apple iPhone 5S',
#  'AMZ_P_875': 'Tensor Computer Mounted Lamp',
#  'AMZ_P_876': 'Logitech Illuminated Ultrathin Keyboard with Backlighting',
#  'AMZ_P_877': 'Serrated Blade or Curved Handle Hand Letter Openers',
#  'AMZ_P_878': 'Premier Automatic Letter Opener',
#  'AMZ_P_879': 'Eldon 300 Class Desk Accessories, Black',
#  'AMZ_P_880': 'Sterilite Show Offs Storage Containers',
#  'AMZ_P_881': 'Logitech G430 Surround Sound Gaming Headset with Dolby 7.1 Technology',
#  'AMZ_P_882': 'Economy #2 Pencils',
#  'AMZ_P_883': 'Maxell DVD-RAM Discs',
#  'AMZ_P_884': 'Global Chrome Stack Chair',
#  'AMZ_P_885': 'Xerox 196',
#  'AMZ_P_886': 'Xerox 1895',
#  'AMZ_P_887': 'Eldon "L" Workstation Diamond Chairmat',
#  'AMZ_P_888': 'DAX Copper Panel Document Frame, 5 x 7 Size',
#  'AMZ_P_889': 'Plantronics CS510 - Over-the-Head monaural Wireless Headset System',
#  'AMZ_P_890': "Eldon ProFile File 'N Store Portable File Tub Letter/Legal Size Black",
#  'AMZ_P_891': 'Riverleaf Stik-Withit Designer Note Cubes',
#  'AMZ_P_892': 'Acco Expandable Hanging Binders',
#  'AMZ_P_893': "High-Back Leather Manager's Chair",
#  'AMZ_P_894': 'Eldon Gobal File Keepers',
#  'AMZ_P_895': 'OIC #2 Pencils, Medium Soft',
#  'AMZ_P_896': 'Avery 505',
#  'AMZ_P_897': 'RCA ViSYS 25423RE1 Corded phone',
#  'AMZ_P_898': 'Eldon Expressions Wood Desk Accessories, Oak',
#  'AMZ_P_899': 'Newell 320',
#  'AMZ_P_900': 'GBC Durable Plastic Covers',
#  'AMZ_P_901': 'Master Giant Foot Doorstop, Safety Yellow',
#  'AMZ_P_902': 'Xerox 1942',
#  'AMZ_P_903': 'Bush Westfield Collection Bookcases, Fully Assembled',
#  'AMZ_P_904': 'DAX Cubicle Frames - 8x10',
#  'AMZ_P_905': 'WD My Passport Ultra 1TB Portable External Hard Drive',
#  'AMZ_P_906': 'Howard Miller 11-1/2" Diameter Brentwood Wall Clock',
#  'AMZ_P_907': "O'Sullivan Elevations Bookcase, Cherry Finish",
#  'AMZ_P_908': 'Jackery Bar Premium Fast-charging Portable Charger',
#  'AMZ_P_909': 'Belkin 7 Outlet SurgeMaster II',
#  'AMZ_P_910': 'Stacking Trays by OIC',
#  'AMZ_P_911': 'Xerox 1981',
#  'AMZ_P_912': 'Mophie Juice Pack Helium for iPhone',
#  'AMZ_P_913': 'Avery 477',
#  'AMZ_P_914': 'Executive Impressions 10" Spectator Wall Clock',
#  'AMZ_P_915': 'Gear Head AU3700S Headset',
#  'AMZ_P_916': 'GBC Poly Designer Binding Covers',
#  'AMZ_P_917': 'Pressboard Covers with Storage Hooks, 9 1/2" x 11", Light Blue',
#  'AMZ_P_918': 'Avery Reinforcements for Hole-Punch Pages',
#  'AMZ_P_919': 'Acco 6 Outlet Guardian Premium Plus Surge Suppressor',
#  'AMZ_P_920': 'Performers Binder/Pad Holder, Black',
#  'AMZ_P_921': 'Tennsco Double-Tier Lockers',
#  'AMZ_P_922': 'Newell 338',
#  'AMZ_P_923': 'Iris Project Case',
#  'AMZ_P_924': 'Global Enterprise Series Seating High-Back Swivel/Tilt Chairs',
#  'AMZ_P_925': 'Xerox 210',
#  'AMZ_P_926': 'Boston Electric Pencil Sharpener, Model 1818, Charcoal Black',
#  'AMZ_P_927': 'Economy Binders',
#  'AMZ_P_928': 'Smead Alpha-Z Color-Coded Second Alphabetical Labels and Starter Set',
#  'AMZ_P_929': 'Safco Value Mate Steel Bookcase, Baked Enamel Finish on Steel, Black',
#  'AMZ_P_930': 'Cubify CubeX 3D Printer Double Head Print',
#  'AMZ_P_931': 'Xerox 1939',
#  'AMZ_P_932': 'Cisco Desktop Collaboration Experience DX650 IP Video Phone',
#  'AMZ_P_933': "O'Sullivan 3-Shelf Heavy-Duty Bookcases",
#  'AMZ_P_934': 'Boston 1827 Commercial Additional Cutter, Drive Gear & Gear Rack for 1606',
#  'AMZ_P_935': 'Chromcraft Bull-Nose Wood Round Conference Table Top, Wood Base',
#  'AMZ_P_936': 'PayAnywhere Card Reader',
#  'AMZ_P_937': 'Harmony Air Purifier',
#  'AMZ_P_938': 'Rogers Jumbo File, Granite',
#  'AMZ_P_939': 'Vtech CS6719',
#  'AMZ_P_940': 'GBC Premium Transparent Covers with Diagonal Lined Pattern',
#  'AMZ_P_941': 'Polycom SoundPoint Pro SE-225 Corded phone',
#  'AMZ_P_942': 'Xerox 2000',
#  'AMZ_P_943': 'Hewlett-Packard Deskjet D4360 Printer',
#  'AMZ_P_944': 'Airmail Envelopes',
#  'AMZ_P_945': 'Mediabridge Sport Armband iPhone 5s',
#  'AMZ_P_946': 'LogitechÂ\xa0LS21 Speaker System - PC Multimedia - 2.1-CH - Wired',
#  'AMZ_P_947': 'Avery Metallic Poly Binders',
#  'AMZ_P_948': '#6 3/4 Gummed Flap White Envelopes',
#  'AMZ_P_949': 'Nu-Dell Float Frame 11 x 14 1/2',
#  'AMZ_P_950': 'Balt Solid Wood Rectangular Table',
#  'AMZ_P_951': 'Polycom SoundPoint IP 450 VoIP phone',
#  'AMZ_P_952': 'SANFORD Major Accent Highlighters',
#  'AMZ_P_953': 'Wilson SignalBoost 841262 DB PRO Amplifier Kit',
#  'AMZ_P_954': 'Southworth 25% Cotton Linen-Finish Paper & Envelopes',
#  'AMZ_P_955': 'Eldon 200 Class Desk Accessories',
#  'AMZ_P_956': 'Xerox 231',
#  'AMZ_P_957': 'Master Caster Door Stop, Brown',
#  'AMZ_P_958': 'Inter-Office Recycled Envelopes, Brown Kraft, Button-String,10" x 13" , 100/Box',
#  'AMZ_P_959': 'Martin Yale Chadless Opener Electric Letter Opener',
#  'AMZ_P_960': 'Gould Plastics 18-Pocket Panel Bin, 34w x 5-1/4d x 20-1/2h',
#  'AMZ_P_961': 'Lenovo 17-Key USB Numeric Keypad',
#  'AMZ_P_962': 'Xerox 1992',
#  'AMZ_P_963': 'Holmes 99% HEPA Air Purifier',
#  'AMZ_P_964': 'Xerox 1892',
#  'AMZ_P_965': 'Chromcraft Round Conference Tables',
#  'AMZ_P_966': 'Xerox 1930',
#  'AMZ_P_967': 'Xerox 211',
#  'AMZ_P_968': 'Xerox 227',
#  'AMZ_P_969': 'Seidio BD2-HK3IPH5-BK DILEX Case and Holster Combo for Apple iPhone 5/5s - Black',
#  'AMZ_P_970': 'Avanti 4.4 Cu. Ft. Refrigerator',
#  'AMZ_P_971': 'Sony 32GB Class 10 Micro SDHC R40 Memory Card',
#  'AMZ_P_972': 'Tennsco Commercial Shelving',
#  'AMZ_P_973': 'Westinghouse Floor Lamp with Metal Mesh Shade, Black',
#  'AMZ_P_974': 'Premier Elliptical Ring Binder, Black',
#  'AMZ_P_975': 'TOPS "Important Message" Pads, Canary, 4-1/4 x 5-1/2, 50 Sheets per Pad',
#  'AMZ_P_976': 'BIC Brite Liner Highlighters',
#  'AMZ_P_977': 'Master Big Foot Doorstop, Beige',
#  'AMZ_P_978': 'Zebra Zazzle Fluorescent Highlighters',
#  'AMZ_P_979': 'Bevis Round Conference Table Top & Single Column Base',
#  'AMZ_P_980': 'Tyvek Side-Opening Peel & Seel Expanding Envelopes',
#  'AMZ_P_981': 'Jensen SMPS-640 -Â\xa0speaker phone',
#  'AMZ_P_982': 'Master Caster Door Stop, Large Brown',
#  'AMZ_P_983': 'Acco Perma 3000 Stacking Storage Drawers',
#  'AMZ_P_984': 'Executive Impressions 13" Chairman Wall Clock',
#  'AMZ_P_985': 'Brother DCP1000 Digital 3 in 1 Multifunction Machine',
#  'AMZ_P_986': 'Newell Chalk Holder',
#  'AMZ_P_987': 'Nontoxic Chalk',
#  'AMZ_P_988': 'GBC Therma-A-Bind 250T Electric Binding System',
#  'AMZ_P_989': 'Super Bands, 12/Pack',
#  'AMZ_P_990': 'Document Clip Frames',
#  'AMZ_P_991': 'Global Armless Task Chair, Royal Blue',
#  'AMZ_P_992': 'Hoover Replacement Belts For Soft Guard & Commercial Ltweight Upright Vacs, 2/Pk',
#  'AMZ_P_993': 'Deflect-o EconoMat Studded, No Bevel Mat for Low Pile Carpeting',
#  'AMZ_P_994': 'Sauder Camden County Collection Library',
#  'AMZ_P_995': 'Boston School Pro Electric Pencil Sharpener, 1670',
#  'AMZ_P_996': 'Office Star - Ergonomic Mid Back Chair with 2-Way Adjustable Arms',
#  'AMZ_P_997': 'Ibico Presentation Index for Binding Systems',
#  'AMZ_P_998': 'Xerox 1917',
#  'AMZ_P_999': 'Acco Banker\'s Clasps, 5 3/4"-Long',
#  'AMZ_P_1000': 'Logitech Media Keyboard K200',
#  ...}

# %% [markdown]
# PERFORMING RFM
#
# AGGREGATING DATA AT CUSTOMER LEVEL: We consolidate the data on a per-customer basis to examine the purchasing patterns of individual customers.

# %%
# Aggregate data by Customer Name
customer_data = df.groupby('Customer Name').agg({
    'Order Date': lambda x: (x.max() - x.min()).days,
    'Order ID': 'count',
    'Sales': 'sum',
    'Profit': 'sum'
}).rename(columns={'Order Date': 'Recency', 'Order ID': 'Frequency', 'Sales': 'TotalSpend'})

customer_data.head()
# Out:
#                 Recency  Frequency  TotalSpend    Profit
# Customer Name
# AaronBergman          0          3     309.592   15.0033
# AaronHawkins        594          5    1328.124  179.8842
# AaronSmayling       373          3     737.028   19.1547
# AdamBellavance      780          5    2693.918  363.7782
# AdamHart            882          5     463.770   99.2752

# %%
def create_quantiles(rfm_file):
    
    """ Function to Create RQM Ranking """
    
    # Add Quantiles Frequency
    quartiles_qty               = rfm_file['Frequency'].drop_duplicates().quantile([.20, .40, .60, 0.80]).tolist()
    quartiles_qty               = [0] + quartiles_qty + [float('inf')]
    
    try:
        rfm_file['Rel_Frequency']   = pd.cut(rfm_file['Frequency'], 
                                             bins=quartiles_qty, 
                                             labels=['1', '2', '3', '4', '5'],
                                             include_lowest=True)
    except:
        rfm_file['Rel_Frequency']   = '2'
    
    # Add Quantiles Monetary Value
    quartiles_price               = rfm_file['TotalSpend'].drop_duplicates().quantile([.20, .40, .60, 0.80]).tolist()
    quartiles_price               = [0] + quartiles_price + [float('inf')]
    
    try:
        rfm_file['Rel_TotalSpend']   = pd.cut(rfm_file['TotalSpend'], 
                                               bins=quartiles_price, 
                                               labels=['1', '2', '3', '4', '5'],
                                               include_lowest=True)
    except:
        rfm_file['Rel_TotalSpend']   = '2'
    
    # Add Quantiles Recency
    quartiles_recency             = rfm_file['Recency'].drop_duplicates().quantile([.20, .40, .60, 0.80]).tolist()
    quartiles_recency             = [0] + quartiles_recency + [float('inf')]
    
    try:
        rfm_file['Rel_Recency'] = pd.cut(rfm_file['Recency'], 
                                               bins=quartiles_recency, 
                                               labels=['5', '4', '3', '2', '1'],
                                               include_lowest=True)
    except:
        rfm_file['Rel_Recency']   = '2'
    
    ## Summing the rqm scores 
    rfm_file['Rqm_Score']         = rfm_file['Rel_Frequency'].astype(int) + \
                                    rfm_file['Rel_TotalSpend'].astype(int) +\
                                    rfm_file['Rel_Recency'].astype(int)
    # Rank the distribution
    rfm_file['Rank']              = rfm_file['Rqm_Score'].rank(ascending=False, method='first')
    
    # Sort Data by Rank
    rfm_file = rfm_file.sort_values(by='Rank', ascending=True).astype({'Rank':int})
    
    return rfm_file

# %%
customer_data_ranked = create_quantiles(customer_data)
customer_data_ranked.head()
# Out:
#                   Recency  Frequency  TotalSpend     Profit Rel_Frequency  \
# Customer Name
# LaurelBeltran         250         14    2836.040  -471.3007             4
# SandraGlassco          46         10    2567.151   352.1862             3
# AlanDominguez          98          5    4353.340  1535.8919             2
# AlanSchoenberger      371          9    2017.184   262.2209             3
# ArthurGainer          523          9    2382.179   169.9962             3
#
#                  Rel_TotalSpend Rel_Recency  Rqm_Score  Rank
# Customer Name
# LaurelBeltran                 5           5         14     1
# SandraGlassco                 5           5         13     2
# AlanDominguez                 5           5         12     3
# AlanSchoenberger              5           4         12     4
# ArthurGainer                  5           4         12     5

# %% [markdown]
# APPLYING THE ELBOW METHOD : To determine the optimal number of clusters for KMeans, we use the Elbow Method

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# Scale the features
scaler = StandardScaler()
scaled_features = scaler.fit_transform(customer_data[['Recency', 'Frequency', 'TotalSpend']])

# Determine the optimal number of clusters using the Elbow Method
wcss = []
for i in range(1, 15):
    kmeans = KMeans(n_clusters=i, init='k-means++', random_state=42)
    kmeans.fit(scaled_features)
    wcss.append(kmeans.inertia_)

# Plot the WCSS for each number of clusters
plt.plot(range(1, 15), wcss, marker='o')
plt.axvline(x=5, color='red', linestyle='--')
plt.title('K-Mean Clustering - Elbow Method')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.grid()
plt.show()

# %% [markdown]
# IMPLEMENTING K-MEANS CLUSTERING  : With the optimal number of clusters determined i.e. 5, we apply the KMeans algorithm.

# %%
# Assuming optimal_clusters is determined from the Elbow plot
optimal_clusters = 5
kmeans = KMeans(n_clusters=optimal_clusters, random_state=42)
customer_data['Segment'] = kmeans.fit_predict(scaled_features)

customer_data
# Out:
#                    Recency  Frequency  TotalSpend     Profit Rel_Frequency  \
# Customer Name
# AaronBergman             0          3     309.592    15.0033             1
# AaronHawkins           594          5    1328.124   179.8842             2
# AaronSmayling          373          3     737.028    19.1547             1
# AdamBellavance         780          5    2693.918   363.7782             2
# AdamHart               882          5     463.770    99.2752             2
# ...                    ...        ...         ...        ...           ...
# XylonaPreis           1100         12     660.190   298.3414             3
# YanaSorensen           744          7    5754.172  1551.5945             2
# YosephCarroll          147          2    1215.676   382.0575             1
# ZuschussCarroll       1121         16    2641.089   346.0942             4
# ZuschussDonatelli     1020          4     306.200    42.4662             1
#
#                   Rel_TotalSpend Rel_Recency  Rqm_Score   Rank  Segment
# Customer Name
# AaronBergman                   2           5          8  270.0        3
# AaronHawkins                   4           3          9  162.0        1
# AaronSmayling                  3           4          8  271.0        3
# AdamBellavance                 5           2          9  163.0        0
# AdamHart                       3           2          7  417.0        1
# ...                          ...         ...        ...    ...      ...
# XylonaPreis                    3           1          7  589.0        2
# YanaSorensen                   5           3         10  159.0        4
# YosephCarroll                  4           5         10  160.0        3
# ZuschussCarroll                5           1         10  161.0        2
# ZuschussDonatelli              2           2          5  673.0        1
#
# [686 rows x 10 columns]

# %% [markdown]
# ANALYZING THE SEGMENTS CHARACTERISTICS

# %%
cluster_analysis = customer_data.groupby('Segment').agg({
    'Recency': 'mean',
    'Frequency': 'mean',
    'TotalSpend': 'mean',
    'Profit': 'mean'
}).sort_values(by='Recency', ascending=True)

cluster_analysis
# Out:
#             Recency  Frequency   TotalSpend       Profit
# Segment
# 3         63.346154   2.083916   365.144549    47.215362
# 0        370.690722   6.268041  2039.290629   243.336015
# 1        853.851852   4.502646   682.609463   103.821172
# 4        874.461538   9.230769  5620.287135  1169.878615
# 2        963.897727  10.318182  1682.666347   241.729731

# %% [markdown]
# From the presented output, it's evident that the KMeans clustering algorithm has partitioned the customer data into four discernible segments or clusters, taking into account factors such as Recency (the time elapsed since their last purchase), Frequency (the rate at which they make purchases), and TotalSpend (the cumulative amount they spend).
#
# Cluster 3:
#
# Recency: On average, customers in this segment made purchases approximately 63.35 days ago, indicating recent engagement with the store.
# Frequency: The average number of transactions for customers in this cluster is 2.08, suggesting a moderate level of engagement.
# TotalSpend: Customers in this cluster spend an average of $365.14 per transaction, indicating a moderate level of expenditure during their visits.
# Profit: The average profit generated from customers in this cluster is $47.22, reflecting the net earnings from their transactions after accounting for costs.
#
# Insights: Customers in this cluster are recent shoppers who make a low number of transactions and have a moderate total spend. While their engagement frequency is not very high, they contribute to a reasonable profit margin. This segment might include new or occasional shoppers who are still exploring the store's offerings.
# Marketing Strategy:To encourage repeat visits and increase spending, consider implementing a first-time buyer or loyalty program, providing welcome discounts, or recommending popular products to increase their purchase frequency and amount.
#
# Cluster 0:
#
# Recency: On average, customers in this segment made purchases approximately 370.69 days ago, indicating less recent engagement with the store.
# Frequency: The average number of transactions for customers in this cluster is 6.27, suggesting a relatively higher level of engagement compared to other clusters.
# TotalSpend: Customers in this cluster spend an average of $2039.29 per transaction, indicating a higher level of expenditure during their visits.
# Profit: The average profit generated from customers in this cluster is $243.34, reflecting the net earnings from their transactions after accounting for costs.
#
# Insights: Customers in this cluster have made purchases relatively recently, with a moderate number of transactions and a high total spend. They are likely regular customers who make consistent purchases, contributing significantly to the store's revenue and profit margin.
# Marketing Strategy:To maintain their loyalty and encourage continued spending, consider offering personalized recommendations based on their purchase history, providing special discounts for frequent shoppers, or launching targeted marketing campaigns to promote related products.
#
# Cluster 1:
#
# Recency: On average, customers in this segment made purchases approximately 853.85 days ago, indicating relatively less recent engagement with the store.
# Frequency: The average number of transactions for customers in this cluster is 4.50, suggesting a moderate level of engagement.
# TotalSpend: Customers in this cluster spend an average of $682.61 per transaction, indicating a moderate level of expenditure during their visits.
# Profit: The average profit generated from customers in this cluster is $103.82, reflecting the net earnings from their transactions after accounting for costs.
#
# Insights: Customers in this cluster have not made purchases recently, with a moderate frequency of transactions and a moderate total spend. This group may include occasional shoppers who haven't engaged with the store recently but have the potential to become more frequent customers.
# Marketing Strategy:To re-engage this segment, consider sending personalized emails or notifications to remind them of their past purchases, offering limited-time discounts or promotions, or showcasing new products to encourage them to return.
#
# Cluster 4:
#
# Recency: On average, customers in this segment made purchases approximately 874.46 days ago, indicating less recent engagement with the store.
# Frequency: The average number of transactions for customers in this cluster is 9.23, suggesting a higher level of engagement compared to other clusters.
# TotalSpend: Customers in this cluster spend an average of $5620.29 per transaction, indicating a higher level of expenditure during their visits.
# Profit: The average profit generated from customers in this cluster is $1169.88, reflecting the net earnings from their transactions after accounting for costs.
#
# Insights: Customers in this cluster have made purchases recently, with a high frequency of transactions and the highest total spend. They are likely loyal customers who make frequent purchases and contribute significantly to revenue and profit margin.
# Marketing Strategy:
# To maintain and strengthen their loyalty, consider offering exclusive rewards or perks for VIP customers, providing early access to new products or sales events, or inviting them to participate in customer feedback programs to further tailor their shopping experience.
#
# Cluster 2:
#
# Recency: On average, customers in this segment made purchases approximately 963.90 days ago, indicating relatively less recent engagement with the store.
# Frequency: The average number of transactions for customers in this cluster is 10.32, suggesting a higher level of engagement compared to other clusters.
# TotalSpend: Customers in this cluster spend an average of $1682.67 per transaction, indicating a moderate level of expenditure during their visits.
# Profit: The average profit generated from customers in this cluster is $241.73, reflecting the net earnings from their transactions after accounting for costs.
#
# Insights: Customers in this cluster have not made purchases recently, but they have a high frequency of transactions and a moderate total spend. They might be dormant customers who were previously active but have since disengaged from the store.
# Marketing Strategy: To reactivate this segment, consider sending targeted reactivation campaigns with incentives such as special discounts or bonuses, reaching out with personalized messages to remind them of their past purchases, or offering incentives for referring friends or family members.

# %% [markdown]
# RADAR CHART

# %%
# r_segment_stats = customer_data.groupby('Segment')[["TotalSpend", "Frequency", "Profit"]].mean()
r_segment_stats = customer_data.groupby('Segment')[["TotalSpend", "Frequency", "Recency"]].mean()

# Normalize the data
segment_stats_normalized = (r_segment_stats - r_segment_stats.min()) / (r_segment_stats.max() - r_segment_stats.min())

# RADAR CHART
angles = np.linspace(0, 2 * np.pi, len(r_segment_stats.columns), endpoint=False).tolist()
angles += angles[:1]  # Close the plot
plt.figure(figsize=(8, 8))
for segment in segment_stats_normalized.index:
    values = segment_stats_normalized.loc[segment].tolist()
    values += values[:1]  # Close the plot
    plt.polar(angles, values, marker='o', label=segment)
plt.xticks(angles[:-1], r_segment_stats.columns)
plt.yticks([0.25, 0.5, 0.75, 1.0])
plt.title('Segment Comparison')
plt.legend(title='Segments')
plt.show()

# %% [markdown]
# PERFORMING LIFT, CONFIDENCE AND SUPPORT
#
# CREATING LIST OF PRODUCTS BY ORDER ID

# %%
df.groupby(by='Order ID').agg({'Product_ID' : lambda x : list(set(x))})
# Out:
#                                                        Product_ID
# Order ID
# CA-2011-100090                             [AMZ_P_295, AMZ_P_410]
# CA-2011-100363                             [AMZ_P_455, AMZ_P_873]
# CA-2011-100860                                       [AMZ_P_1476]
# CA-2011-100867                                        [AMZ_P_458]
# CA-2011-100881                                        [AMZ_P_209]
# ...                                                           ...
# US-2014-163657                            [AMZ_P_223, AMZ_P_1341]
# US-2014-163790  [AMZ_P_989, AMZ_P_987, AMZ_P_990, AMZ_P_274, A...
# US-2014-166688                [AMZ_P_1051, AMZ_P_188, AMZ_P_1303]
# US-2014-167318                            [AMZ_P_278, AMZ_P_1109]
# US-2014-168802                                       [AMZ_P_1408]
#
# [1611 rows x 1 columns]

# %%
transactions = df.groupby('Order ID')['Product_ID'].apply(list).reset_index(name='items')

transactions['items'] = transactions['items'].apply(lambda x: list(set(x)))

transaction_list = transactions['items'].tolist()

# %%
encoder = TransactionEncoder()
transaction_array = encoder.fit(transaction_list).transform(transaction_list)
df_transactions = pd.DataFrame(transaction_array, columns=encoder.columns_)

# Mining frequent itemsets using FP-growth
frequent_itemsets = fpgrowth(df_transactions, min_support=0.001, use_colnames=True)

print(frequent_itemsets)
# Out:
#       support                  itemsets
# 0    0.001862               (AMZ_P_295)
# 1    0.001241               (AMZ_P_410)
# 2    0.001862               (AMZ_P_455)
# 3    0.001241               (AMZ_P_458)
# 4    0.001241               (AMZ_P_209)
# ..        ...                       ...
# 934  0.001241    (AMZ_P_673, AMZ_P_058)
# 935  0.001241    (AMZ_P_769, AMZ_P_058)
# 936  0.001241    (AMZ_P_161, AMZ_P_160)
# 937  0.001241    (AMZ_P_192, AMZ_P_191)
# 938  0.001241  (AMZ_P_1271, AMZ_P_1272)
#
# [939 rows x 2 columns]

# %%
# Association Rules 

association_rules_df = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.4)

# print(association_rules_df)

association_rules_df = pd.DataFrame(association_rules_df)

# Adding product names to association rules dataframe 
for index, row in association_rules_df.iterrows():
    antecedent = list(row['antecedents'])[0]  
    consequent = list(row['consequents'])[0]

    # Get the product names from product id to product names dictionary
    antecedent_name = product_id_to_name.get(antecedent, antecedent)
    consequent_name = product_id_to_name.get(consequent, consequent)

    # Add the product names to the dataframe
    association_rules_df.at[index, 'antecedent_name'] = antecedent_name
    association_rules_df.at[index, 'consequent_name'] = consequent_name

# Reorder the columns
association_rules_df = association_rules_df.reindex(columns=['antecedents', 'antecedent_name', 'consequents', 'consequent_name', 
                                                            'antecedent support', 'consequent support', 'support', 
                                                            'confidence', 'lift', 'leverage', 'conviction', 'zhangs_metric'])

# Convert frozen sets to single values
association_rules_df['antecedents'] = association_rules_df['antecedents'].apply(lambda x: next(iter(x)))
association_rules_df['consequents'] = association_rules_df['consequents'].apply(lambda x: next(iter(x)))

print(association_rules_df)

# Export to csv file
association_rules_df.to_csv('./results/association_rules.csv', index=False)
# Out:
#   antecedents                                    antecedent_name consequents  \
# 0   AMZ_P_119         O'Sullivan 4-Shelf Bookcase in Odessa Pine   AMZ_P_466
# 1   AMZ_P_466  GBC Standard Recycled Report Covers, Clear Pla...   AMZ_P_119
# 2   AMZ_P_198                       Tennsco Regal Shelving Units   AMZ_P_058
# 3   AMZ_P_818                             GBC Wire Binding Combs   AMZ_P_218
# 4   AMZ_P_673  Wirebound Four 2-3/4 x 5 Forms per Page, 400 S...   AMZ_P_058
# 5   AMZ_P_769         #10 White Business Envelopes,4 1/8 x 9 1/2   AMZ_P_058
# 6   AMZ_P_160                       Advantus Rolling Storage Box   AMZ_P_161
# 7   AMZ_P_192                                         Xerox 1894   AMZ_P_191
# 8  AMZ_P_1271          Microsoft Natural Ergonomic Keyboard 4000  AMZ_P_1272
# 9  AMZ_P_1272  Boston 16765 Mini Stand Up Battery Pencil Shar...  AMZ_P_1271
#
#                                      consequent_name  antecedent support  \
# 0  GBC Standard Recycled Report Covers, Clear Pla...            0.002483
# 1         O'Sullivan 4-Shelf Bookcase in Odessa Pine            0.002483
# 2                                            Staples            0.002483
# 3  Carina Double Wide Media Storage Towers in Nat...            0.001862
# 4                                            Staples            0.002483
# 5                                            Staples            0.001241
# 6  Great White Multi-Use Recycled Paper (20Lb. an...            0.001862
# 7                                          Xerox 225            0.002483
# 8  Boston 16765 Mini Stand Up Battery Pencil Shar...            0.001862
# 9          Microsoft Natural Ergonomic Keyboard 4000            0.001241
#
#    consequent support   support  confidence        lift  leverage  conviction  \
# 0            0.002483  0.001241    0.500000  201.375000  0.001235    1.995034
# 1            0.002483  0.001241    0.500000  201.375000  0.001235    1.995034
# 2            0.036002  0.001241    0.500000   13.887931  0.001152    1.927995
# 3            0.003724  0.001241    0.666667  179.000000  0.001235    2.988827
# 4            0.036002  0.001241    0.500000   13.887931  0.001152    1.927995
# 5            0.036002  0.001241    1.000000   27.775862  0.001197         inf
# 6            0.003104  0.001241    0.666667  214.800000  0.001236    2.990689
# 7            0.004345  0.001241    0.500000  115.071429  0.001231    1.991310
# 8            0.001241  0.001241    0.666667  537.000000  0.001239    2.996276
# 9            0.001862  0.001241    1.000000  537.000000  0.001239         inf
#
#    zhangs_metric
# 0       0.997511
# 1       0.997511
# 2       0.930305
# 3       0.996269
# 4       0.930305
# 5       0.965196
# 6       0.997201
# 7       0.993777
# 8       1.000000
# 9       0.999378

# %%
# Dictionary with customer id and the associated product ids

customer_products = df.groupby('Customer Name')['Product_ID'].agg(list).to_dict()

# Customer list to whom products will be recommended based on association rules 

customers_list = []
customers_association_rule_list = []

for index, row in association_rules_df.iterrows():
    product_X = row['antecedents']
    product_Y = row['consequents']   

    for customer, products in customer_products.items():
        if product_X in products and product_Y not in products:
            customers_list.append(['RECOM', customer, product_X, product_Y])

    
    for customer, products in customer_products.items():
        if product_X in products and product_Y in products:
            customers_association_rule_list.append(['AR', customer, product_X, product_Y])

merged_list = []

for recom_item in customers_list:
    for ar_item in customers_association_rule_list:
        if recom_item[2:] == ar_item[2:4]:
            merged_list.append(recom_item + ar_item[1:])

print(merged_list)
# Out:
# [['RECOM', 'JustinRitter', 'AMZ_P_119', 'AMZ_P_466', 'JulianaKrohn', 'AMZ_P_119', 'AMZ_P_466'], ['RECOM', 'JustinRitter', 'AMZ_P_119', 'AMZ_P_466', 'TobySwindell', 'AMZ_P_119', 'AMZ_P_466'], ['RECOM', 'KeithHerrera', 'AMZ_P_119', 'AMZ_P_466', 'JulianaKrohn', 'AMZ_P_119', 'AMZ_P_466'], ['RECOM', 'KeithHerrera', 'AMZ_P_119', 'AMZ_P_466', 'TobySwindell', 'AMZ_P_119', 'AMZ_P_466'], ['RECOM', 'MarkHaberlin', 'AMZ_P_466', 'AMZ_P_119', 'JulianaKrohn', 'AMZ_P_466', 'AMZ_P_119'], ['RECOM', 'MarkHaberlin', 'AMZ_P_466', 'AMZ_P_119', 'TobySwindell', 'AMZ_P_466', 'AMZ_P_119'], ['RECOM', 'PatrickGardner', 'AMZ_P_466', 'AMZ_P_119', 'JulianaKrohn', 'AMZ_P_466', 'AMZ_P_119'], ['RECOM', 'PatrickGardner', 'AMZ_P_466', 'AMZ_P_119', 'TobySwindell', 'AMZ_P_466', 'AMZ_P_119'], ['RECOM', 'FredMcMath', 'AMZ_P_198', 'AMZ_P_058', 'AlanBarnes', 'AMZ_P_198', 'AMZ_P_058'], ['RECOM', 'FredMcMath', 'AMZ_P_198', 'AMZ_P_058', 'GregGuthrie', 'AMZ_P_198', 'AMZ_P_058'], ['RECOM', 'ScottWilliamson', 'AMZ_P_198', 'AMZ_P_058', 'AlanBarnes', 'AMZ_P_198', 'AMZ_P_058'], ['RECOM', 'ScottWilliamson', 'AMZ_P_198', 'AMZ_P_058', 'GregGuthrie', 'AMZ_P_198', 'AMZ_P_058'], ['RECOM', 'AlanBarnes', 'AMZ_P_818', 'AMZ_P_218', 'CassandraBrandow', 'AMZ_P_818', 'AMZ_P_218'], ['RECOM', 'AlanBarnes', 'AMZ_P_818', 'AMZ_P_218', 'JasonFortune-', 'AMZ_P_818', 'AMZ_P_218'], ['RECOM', 'ChadSievert', 'AMZ_P_673', 'AMZ_P_058', 'HerbertFlentye', 'AMZ_P_673', 'AMZ_P_058'], ['RECOM', 'ChadSievert', 'AMZ_P_673', 'AMZ_P_058', 'LenaCacioppo', 'AMZ_P_673', 'AMZ_P_058'], ['RECOM', 'PenelopeSewall', 'AMZ_P_673', 'AMZ_P_058', 'HerbertFlentye', 'AMZ_P_673', 'AMZ_P_058'], ['RECOM', 'PenelopeSewall', 'AMZ_P_673', 'AMZ_P_058', 'LenaCacioppo', 'AMZ_P_673', 'AMZ_P_058'], ['RECOM', 'CynthiaDelaney', 'AMZ_P_160', 'AMZ_P_161', 'AlanDominguez', 'AMZ_P_160', 'AMZ_P_161'], ['RECOM', 'CynthiaDelaney', 'AMZ_P_160', 'AMZ_P_161', 'ChuckMagee', 'AMZ_P_160', 'AMZ_P_161'], ['RECOM', 'DennyJoy', 'AMZ_P_192', 'AMZ_P_191', 'JenniferFerguson', 'AMZ_P_192', 'AMZ_P_191'], ['RECOM', 'DennyJoy', 'AMZ_P_192', 'AMZ_P_191', 'ZuschussCarroll', 'AMZ_P_192', 'AMZ_P_191'], ['RECOM', 'JohnLucas', 'AMZ_P_192', 'AMZ_P_191', 'JenniferFerguson', 'AMZ_P_192', 'AMZ_P_191'], ['RECOM', 'JohnLucas', 'AMZ_P_192', 'AMZ_P_191', 'ZuschussCarroll', 'AMZ_P_192', 'AMZ_P_191'], ['RECOM', 'KalycaMeade', 'AMZ_P_1271', 'AMZ_P_1272', 'DavePoirier', 'AMZ_P_1271', 'AMZ_P_1272'], ['RECOM', 'KalycaMeade', 'AMZ_P_1271', 'AMZ_P_1272', 'WilliamBrown', 'AMZ_P_1271', 'AMZ_P_1272']]

# %%
int_df = pd.DataFrame(merged_list, columns=['Type', 'Recom_Cust_Name', 'Recom_Product1', 'Recom_Product', 'AR_Cust_Name', 'AR_Product1', 'AR_Product2'])

# Changing 'Type' column values to 'AR'
int_df.loc[:, 'Type'] = 'AR'

selected_cols = ['Recom_Cust_Name', 'Recom_Product', 'Type', 'AR_Cust_Name', 'AR_Product1', 'AR_Product2']
int_df = int_df[selected_cols]

final_df = int_df.drop_duplicates(subset=['Recom_Cust_Name', 'Recom_Product'])

final_df = final_df.reset_index(drop=True)

final_df
# Out:
#     Recom_Cust_Name Recom_Product Type      AR_Cust_Name AR_Product1  \
# 0      JustinRitter     AMZ_P_466   AR      JulianaKrohn   AMZ_P_119
# 1      KeithHerrera     AMZ_P_466   AR      JulianaKrohn   AMZ_P_119
# 2      MarkHaberlin     AMZ_P_119   AR      JulianaKrohn   AMZ_P_466
# 3    PatrickGardner     AMZ_P_119   AR      JulianaKrohn   AMZ_P_466
# 4        FredMcMath     AMZ_P_058   AR        AlanBarnes   AMZ_P_198
# 5   ScottWilliamson     AMZ_P_058   AR        AlanBarnes   AMZ_P_198
# 6        AlanBarnes     AMZ_P_218   AR  CassandraBrandow   AMZ_P_818
# 7       ChadSievert     AMZ_P_058   AR    HerbertFlentye   AMZ_P_673
# 8    PenelopeSewall     AMZ_P_058   AR    HerbertFlentye   AMZ_P_673
# 9    CynthiaDelaney     AMZ_P_161   AR     AlanDominguez   AMZ_P_160
# 10         DennyJoy     AMZ_P_191   AR  JenniferFerguson   AMZ_P_192
# 11        JohnLucas     AMZ_P_191   AR  JenniferFerguson   AMZ_P_192
# 12      KalycaMeade    AMZ_P_1272   AR       DavePoirier  AMZ_P_1271
#
#    AR_Product2
# 0    AMZ_P_466
# 1    AMZ_P_466
# 2    AMZ_P_119
# 3    AMZ_P_119
# 4    AMZ_P_058
# 5    AMZ_P_058
# 6    AMZ_P_218
# 7    AMZ_P_058
# 8    AMZ_P_058
# 9    AMZ_P_161
# 10   AMZ_P_191
# 11   AMZ_P_191
# 12  AMZ_P_1272

# %%
for customer_info in final_df.iterrows():
    customer_info[1][1] = product_id_to_name.get(customer_info[1][1], customer_info[1][1])
    customer_info[1][4] = product_id_to_name.get(customer_info[1][4], customer_info[1][4])
    customer_info[1][5] = product_id_to_name.get(customer_info[1][5], customer_info[1][5])

final_df
# Out:
#     Recom_Cust_Name                                      Recom_Product Type  \
# 0      JustinRitter  GBC Standard Recycled Report Covers, Clear Pla...   AR
# 1      KeithHerrera  GBC Standard Recycled Report Covers, Clear Pla...   AR
# 2      MarkHaberlin         O'Sullivan 4-Shelf Bookcase in Odessa Pine   AR
# 3    PatrickGardner         O'Sullivan 4-Shelf Bookcase in Odessa Pine   AR
# 4        FredMcMath                                            Staples   AR
# 5   ScottWilliamson                                            Staples   AR
# 6        AlanBarnes  Carina Double Wide Media Storage Towers in Nat...   AR
# 7       ChadSievert                                            Staples   AR
# 8    PenelopeSewall                                            Staples   AR
# 9    CynthiaDelaney  Great White Multi-Use Recycled Paper (20Lb. an...   AR
# 10         DennyJoy                                          Xerox 225   AR
# 11        JohnLucas                                          Xerox 225   AR
# 12      KalycaMeade  Boston 16765 Mini Stand Up Battery Pencil Shar...   AR
#
#         AR_Cust_Name                                        AR_Product1  \
# 0       JulianaKrohn         O'Sullivan 4-Shelf Bookcase in Odessa Pine
# 1       JulianaKrohn         O'Sullivan 4-Shelf Bookcase in Odessa Pine
# 2       JulianaKrohn  GBC Standard Recycled Report Covers, Clear Pla...
# 3       JulianaKrohn  GBC Standard Recycled Report Covers, Clear Pla...
# 4         AlanBarnes                       Tennsco Regal Shelving Units
# 5         AlanBarnes                       Tennsco Regal Shelving Units
# 6   CassandraBrandow                             GBC Wire Binding Combs
# 7     HerbertFlentye  Wirebound Four 2-3/4 x 5 Forms per Page, 400 S...
# 8     HerbertFlentye  Wirebound Four 2-3/4 x 5 Forms per Page, 400 S...
# 9      AlanDominguez                       Advantus Rolling Storage Box
# 10  JenniferFerguson                                         Xerox 1894
# 11  JenniferFerguson                                         Xerox 1894
# 12       DavePoirier          Microsoft Natural Ergonomic Keyboard 4000
#
#                                           AR_Product2
# 0   GBC Standard Recycled Report Covers, Clear Pla...
# 1   GBC Standard Recycled Report Covers, Clear Pla...
# 2          O'Sullivan 4-Shelf Bookcase in Odessa Pine
# 3          O'Sullivan 4-Shelf Bookcase in Odessa Pine
# 4                                             Staples
# 5                                             Staples
# 6   Carina Double Wide Media Storage Towers in Nat...
# 7                                             Staples
# 8                                             Staples
# 9   Great White Multi-Use Recycled Paper (20Lb. an...
# 10                                          Xerox 225
# 11                                          Xerox 225
# 12  Boston 16765 Mini Stand Up Battery Pencil Shar...

# %%
# Generating statements and assigning them to the 'Recommendations' column
final_df['Recommendations'] = final_df.apply(lambda row: f"The customer {row['Recom_Cust_Name']} has been recommended with product {row['Recom_Product']} because, as per association rules, he has bought product {row['AR_Product1']} and not {row['AR_Product2']}.", axis=1)

final_df['Rank'] = final_df['Recom_Cust_Name'].map(customer_data['Rank'])
final_df['Segment'] = final_df['Recom_Cust_Name'].map(customer_data['Segment'])

final_df = final_df.sort_values(by=['Rank', 'Segment'])

print(final_df)

final_df.to_csv('./results/final_df.csv', index=False)
# Out:
#     Recom_Cust_Name                                      Recom_Product Type  \
# 11        JohnLucas                                          Xerox 225   AR
# 8    PenelopeSewall                                            Staples   AR
# 12      KalycaMeade  Boston 16765 Mini Stand Up Battery Pencil Shar...   AR
# 1      KeithHerrera  GBC Standard Recycled Report Covers, Clear Pla...   AR
# 4        FredMcMath                                            Staples   AR
# 5   ScottWilliamson                                            Staples   AR
# 6        AlanBarnes  Carina Double Wide Media Storage Towers in Nat...   AR
# 7       ChadSievert                                            Staples   AR
# 9    CynthiaDelaney  Great White Multi-Use Recycled Paper (20Lb. an...   AR
# 0      JustinRitter  GBC Standard Recycled Report Covers, Clear Pla...   AR
# 3    PatrickGardner         O'Sullivan 4-Shelf Bookcase in Odessa Pine   AR
# 10         DennyJoy                                          Xerox 225   AR
# 2      MarkHaberlin         O'Sullivan 4-Shelf Bookcase in Odessa Pine   AR
#
#         AR_Cust_Name                                        AR_Product1  \
# 11  JenniferFerguson                                         Xerox 1894
# 8     HerbertFlentye  Wirebound Four 2-3/4 x 5 Forms per Page, 400 S...
# 12       DavePoirier          Microsoft Natural Ergonomic Keyboard 4000
# 1       JulianaKrohn         O'Sullivan 4-Shelf Bookcase in Odessa Pine
# 4         AlanBarnes                       Tennsco Regal Shelving Units
# 5         AlanBarnes                       Tennsco Regal Shelving Units
# 6   CassandraBrandow                             GBC Wire Binding Combs
# 7     HerbertFlentye  Wirebound Four 2-3/4 x 5 Forms per Page, 400 S...
# 9      AlanDominguez                       Advantus Rolling Storage Box
# 0       JulianaKrohn         O'Sullivan 4-Shelf Bookcase in Odessa Pine
# 3       JulianaKrohn  GBC Standard Recycled Report Covers, Clear Pla...
# 10  JenniferFerguson                                         Xerox 1894
# 2       JulianaKrohn  GBC Standard Recycled Report Covers, Clear Pla...
#
#                                           AR_Product2  \
# 11                                          Xerox 225
# 8                                             Staples
# 12  Boston 16765 Mini Stand Up Battery Pencil Shar...
# 1   GBC Standard Recycled Report Covers, Clear Pla...
# 4                                             Staples
# 5                                             Staples
# 6   Carina Double Wide Media Storage Towers in Nat...
# 7                                             Staples
# 9   Great White Multi-Use Recycled Paper (20Lb. an...
# 0   GBC Standard Recycled Report Covers, Clear Pla...
# 3          O'Sullivan 4-Shelf Bookcase in Odessa Pine
# 10                                          Xerox 225
# 2          O'Sullivan 4-Shelf Bookcase in Odessa Pine
#
#                                       Recommendations   Rank  Segment
# 11  The customer JohnLucas has been recommended wi...   17.0        0
# 8   The customer PenelopeSewall has been recommend...   71.0        0
# 12  The customer KalycaMeade has been recommended ...  118.0        3
# 1   The customer KeithHerrera has been recommended...  121.0        4
# 4   The customer FredMcMath has been recommended w...  204.0        3
# 5   The customer ScottWilliamson has been recommen...  256.0        3
# 6   The customer AlanBarnes has been recommended w...  272.0        2
# 7   The customer ChadSievert has been recommended ...  299.0        1
# 9   The customer CynthiaDelaney has been recommend...  306.0        1
# 0   The customer JustinRitter has been recommended...  343.0        1
# 3   The customer PatrickGardner has been recommend...  377.0        2
# 10  The customer DennyJoy has been recommended wit...  463.0        3
# 2   The customer MarkHaberlin has been recommended...  526.0        3
